# %% [markdown]
# # 0. Setup Paths

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# %cd drive/MyDrive/MINST
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/MINST'
# /content/drive/MyDrive/MINST/Tensorflow

# %%
# !apt-get install protobuf-compiler
# !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install .

# %%
import object_detection

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet'
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME),
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'),
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'),
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'),
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME),
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %% [markdown]
# # 6. Train the model

# %%
labels = [{'name':'Hello', 'id':1}, {'name':'Yes', 'id':2}, {'name':'No', 'id':3}, {'name':'Thank You', 'id':4}, {'name':'I Love You', 'id':5}]
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=20000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=20000

# %%
# !{command}
# Out:
# 2023-02-10 11:58:16.658614: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-10 11:58:16.658733: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-10 11:58:16.658757: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-10 11:58:20.520933: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0210 11:58:20.540550 140265946711872 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 20000
# I0210 11:58:20.544107 140265946711872 config_util.py:552] Maybe overwriting train_steps: 20000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0210 11:58:20.544251 140265946711872 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0210 11:58:20.570182 140265946711872 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0210 11:58:20.577131 140265946711872 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0210 11:58:20.577436 140265946711872 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0210 11:58:20.577538 140265946711872 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0210 11:58:20.577606 140265946711872 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0210 11:58:20.583455 140265946711872 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0210 11:58:20.599953 140265946711872 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0210 11:58:21.134559 140265946711872 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0210 11:58:29.921730 140265946711872 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0210 11:58:32.761949 140265946711872 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0210 11:58:34.195950 140265946711872 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2023-02-10 11:58:39.218829: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 64366272 exceeds 10% of free system memory.
# 2023-02-10 11:58:39.290820: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 52108272 exceeds 10% of free system memory.
# 2023-02-10 11:58:39.348742: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 52108272 exceeds 10% of free system memory.
# 2023-02-10 11:58:39.401466: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 64366272 exceeds 10% of free system memory.
# 2023-02-10 11:58:39.468226: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 53472528 exceeds 10% of free system memory.
# /usr/local/lib/python3.8/dist-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.851087 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.853814 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.854871 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.855854 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.859328 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.860279 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.861258 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.862202 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.866752 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0210 11:59:18.867710 140265946711872 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0210 11:59:20.069763 140261721544448 deprecation.py:554] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 1.076s
# I0210 12:01:07.480353 140265946711872 model_lib_v2.py:705] Step 100 per-step time 1.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.25423506,
#  'Loss/localization_loss': 0.3037604,
#  'Loss/regularization_loss': 0.15418197,
#  'Loss/total_loss': 0.7121774,
#  'learning_rate': 0.0319994}
# I0210 12:01:07.480878 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.25423506,
#  'Loss/localization_loss': 0.3037604,
#  'Loss/regularization_loss': 0.15418197,
#  'Loss/total_loss': 0.7121774,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.628s
# I0210 12:02:10.178875 140265946711872 model_lib_v2.py:705] Step 200 per-step time 0.628s
# INFO:tensorflow:{'Loss/classification_loss': 0.24319434,
#  'Loss/localization_loss': 0.17668763,
#  'Loss/regularization_loss': 0.15423103,
#  'Loss/total_loss': 0.574113,
#  'learning_rate': 0.0373328}
# I0210 12:02:10.179243 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.24319434,
#  'Loss/localization_loss': 0.17668763,
#  'Loss/regularization_loss': 0.15423103,
#  'Loss/total_loss': 0.574113,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.616s
# I0210 12:03:11.815555 140265946711872 model_lib_v2.py:705] Step 300 per-step time 0.616s
# INFO:tensorflow:{'Loss/classification_loss': 0.31874007,
#  'Loss/localization_loss': 0.14473185,
#  'Loss/regularization_loss': 0.15436018,
#  'Loss/total_loss': 0.61783206,
#  'learning_rate': 0.0426662}
# I0210 12:03:11.815977 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.31874007,
#  'Loss/localization_loss': 0.14473185,
#  'Loss/regularization_loss': 0.15436018,
#  'Loss/total_loss': 0.61783206,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.606s
# I0210 12:04:12.445269 140265946711872 model_lib_v2.py:705] Step 400 per-step time 0.606s
# INFO:tensorflow:{'Loss/classification_loss': 0.17648172,
#  'Loss/localization_loss': 0.1482084,
#  'Loss/regularization_loss': 0.15412354,
#  'Loss/total_loss': 0.47881365,
#  'learning_rate': 0.047999598}
# I0210 12:04:12.445833 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.17648172,
#  'Loss/localization_loss': 0.1482084,
#  'Loss/regularization_loss': 0.15412354,
#  'Loss/total_loss': 0.47881365,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.560s
# I0210 12:05:08.469789 140265946711872 model_lib_v2.py:705] Step 500 per-step time 0.560s
# INFO:tensorflow:{'Loss/classification_loss': 0.114853166,
#  'Loss/localization_loss': 0.056450594,
#  'Loss/regularization_loss': 0.15384364,
#  'Loss/total_loss': 0.3251474,
#  'learning_rate': 0.053333}
# I0210 12:05:08.474906 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.114853166,
#  'Loss/localization_loss': 0.056450594,
#  'Loss/regularization_loss': 0.15384364,
#  'Loss/total_loss': 0.3251474,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.601s
# I0210 12:06:08.634911 140265946711872 model_lib_v2.py:705] Step 600 per-step time 0.601s
# INFO:tensorflow:{'Loss/classification_loss': 0.17531417,
#  'Loss/localization_loss': 0.13876146,
#  'Loss/regularization_loss': 0.1535302,
#  'Loss/total_loss': 0.46760583,
#  'learning_rate': 0.0586664}
# I0210 12:06:08.635333 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.17531417,
#  'Loss/localization_loss': 0.13876146,
#  'Loss/regularization_loss': 0.1535302,
#  'Loss/total_loss': 0.46760583,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.547s
# I0210 12:07:03.345609 140265946711872 model_lib_v2.py:705] Step 700 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.08804914,
#  'Loss/localization_loss': 0.034102328,
#  'Loss/regularization_loss': 0.15322144,
#  'Loss/total_loss': 0.27537292,
#  'learning_rate': 0.0639998}
# I0210 12:07:03.350052 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.08804914,
#  'Loss/localization_loss': 0.034102328,
#  'Loss/regularization_loss': 0.15322144,
#  'Loss/total_loss': 0.27537292,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.631s
# I0210 12:08:06.452778 140265946711872 model_lib_v2.py:705] Step 800 per-step time 0.631s
# INFO:tensorflow:{'Loss/classification_loss': 0.19126113,
#  'Loss/localization_loss': 0.11996919,
#  'Loss/regularization_loss': 0.15280178,
#  'Loss/total_loss': 0.46403208,
#  'learning_rate': 0.069333196}
# I0210 12:08:06.453171 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.19126113,
#  'Loss/localization_loss': 0.11996919,
#  'Loss/regularization_loss': 0.15280178,
#  'Loss/total_loss': 0.46403208,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.560s
# I0210 12:09:02.461556 140265946711872 model_lib_v2.py:705] Step 900 per-step time 0.560s
# INFO:tensorflow:{'Loss/classification_loss': 0.15874778,
#  'Loss/localization_loss': 0.077117085,
#  'Loss/regularization_loss': 0.15235828,
#  'Loss/total_loss': 0.38822314,
#  'learning_rate': 0.074666604}
# I0210 12:09:02.463002 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.15874778,
#  'Loss/localization_loss': 0.077117085,
#  'Loss/regularization_loss': 0.15235828,
#  'Loss/total_loss': 0.38822314,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.582s
# I0210 12:10:00.618245 140265946711872 model_lib_v2.py:705] Step 1000 per-step time 0.582s
# INFO:tensorflow:{'Loss/classification_loss': 0.10717112,
#  'Loss/localization_loss': 0.057946708,
#  'Loss/regularization_loss': 0.15182309,
#  'Loss/total_loss': 0.3169409,
#  'learning_rate': 0.08}
# I0210 12:10:00.618602 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.10717112,
#  'Loss/localization_loss': 0.057946708,
#  'Loss/regularization_loss': 0.15182309,
#  'Loss/total_loss': 0.3169409,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.629s
# I0210 12:11:03.539478 140265946711872 model_lib_v2.py:705] Step 1100 per-step time 0.629s
# INFO:tensorflow:{'Loss/classification_loss': 0.09966715,
#  'Loss/localization_loss': 0.0477219,
#  'Loss/regularization_loss': 0.15156189,
#  'Loss/total_loss': 0.29895094,
#  'learning_rate': 0.07999918}
# I0210 12:11:03.541131 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.09966715,
#  'Loss/localization_loss': 0.0477219,
#  'Loss/regularization_loss': 0.15156189,
#  'Loss/total_loss': 0.29895094,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.594s
# I0210 12:12:02.902645 140265946711872 model_lib_v2.py:705] Step 1200 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.09313944,
#  'Loss/localization_loss': 0.06175862,
#  'Loss/regularization_loss': 0.15148337,
#  'Loss/total_loss': 0.30638143,
#  'learning_rate': 0.079996705}
# I0210 12:12:02.907846 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.09313944,
#  'Loss/localization_loss': 0.06175862,
#  'Loss/regularization_loss': 0.15148337,
#  'Loss/total_loss': 0.30638143,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.542s
# I0210 12:12:57.131823 140265946711872 model_lib_v2.py:705] Step 1300 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.11680478,
#  'Loss/localization_loss': 0.042923328,
#  'Loss/regularization_loss': 0.15099481,
#  'Loss/total_loss': 0.31072292,
#  'learning_rate': 0.0799926}
# I0210 12:12:57.137946 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.11680478,
#  'Loss/localization_loss': 0.042923328,
#  'Loss/regularization_loss': 0.15099481,
#  'Loss/total_loss': 0.31072292,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.555s
# I0210 12:13:52.646321 140265946711872 model_lib_v2.py:705] Step 1400 per-step time 0.555s
# INFO:tensorflow:{'Loss/classification_loss': 0.14003678,
#  'Loss/localization_loss': 0.04065565,
#  'Loss/regularization_loss': 0.15031992,
#  'Loss/total_loss': 0.33101237,
#  'learning_rate': 0.07998685}
# I0210 12:13:52.646709 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.14003678,
#  'Loss/localization_loss': 0.04065565,
#  'Loss/regularization_loss': 0.15031992,
#  'Loss/total_loss': 0.33101237,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.612s
# I0210 12:14:53.877859 140265946711872 model_lib_v2.py:705] Step 1500 per-step time 0.612s
# INFO:tensorflow:{'Loss/classification_loss': 0.04120795,
#  'Loss/localization_loss': 0.04541829,
#  'Loss/regularization_loss': 0.14966157,
#  'Loss/total_loss': 0.2362878,
#  'learning_rate': 0.07997945}
# I0210 12:14:53.878261 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.04120795,
#  'Loss/localization_loss': 0.04541829,
#  'Loss/regularization_loss': 0.14966157,
#  'Loss/total_loss': 0.2362878,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.525s
# I0210 12:15:46.363870 140265946711872 model_lib_v2.py:705] Step 1600 per-step time 0.525s
# INFO:tensorflow:{'Loss/classification_loss': 0.08552818,
#  'Loss/localization_loss': 0.03215913,
#  'Loss/regularization_loss': 0.1489873,
#  'Loss/total_loss': 0.2666746,
#  'learning_rate': 0.079970405}
# I0210 12:15:46.364243 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.08552818,
#  'Loss/localization_loss': 0.03215913,
#  'Loss/regularization_loss': 0.1489873,
#  'Loss/total_loss': 0.2666746,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.521s
# I0210 12:16:38.479566 140265946711872 model_lib_v2.py:705] Step 1700 per-step time 0.521s
# INFO:tensorflow:{'Loss/classification_loss': 0.12986039,
#  'Loss/localization_loss': 0.098784596,
#  'Loss/regularization_loss': 0.14855261,
#  'Loss/total_loss': 0.3771976,
#  'learning_rate': 0.07995972}
# I0210 12:16:38.479960 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.12986039,
#  'Loss/localization_loss': 0.098784596,
#  'Loss/regularization_loss': 0.14855261,
#  'Loss/total_loss': 0.3771976,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.568s
# I0210 12:17:35.275296 140265946711872 model_lib_v2.py:705] Step 1800 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.08502215,
#  'Loss/localization_loss': 0.037174437,
#  'Loss/regularization_loss': 0.1478969,
#  'Loss/total_loss': 0.2700935,
#  'learning_rate': 0.0799474}
# I0210 12:17:35.278086 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.08502215,
#  'Loss/localization_loss': 0.037174437,
#  'Loss/regularization_loss': 0.1478969,
#  'Loss/total_loss': 0.2700935,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.557s
# I0210 12:18:30.923905 140265946711872 model_lib_v2.py:705] Step 1900 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.19257261,
#  'Loss/localization_loss': 0.048860062,
#  'Loss/regularization_loss': 0.14726596,
#  'Loss/total_loss': 0.38869864,
#  'learning_rate': 0.07993342}
# I0210 12:18:30.924327 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.19257261,
#  'Loss/localization_loss': 0.048860062,
#  'Loss/regularization_loss': 0.14726596,
#  'Loss/total_loss': 0.38869864,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.575s
# I0210 12:19:28.453592 140265946711872 model_lib_v2.py:705] Step 2000 per-step time 0.575s
# INFO:tensorflow:{'Loss/classification_loss': 0.06790506,
#  'Loss/localization_loss': 0.012422111,
#  'Loss/regularization_loss': 0.14685966,
#  'Loss/total_loss': 0.22718683,
#  'learning_rate': 0.07991781}
# I0210 12:19:28.460939 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.06790506,
#  'Loss/localization_loss': 0.012422111,
#  'Loss/regularization_loss': 0.14685966,
#  'Loss/total_loss': 0.22718683,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.539s
# I0210 12:20:22.349956 140265946711872 model_lib_v2.py:705] Step 2100 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.04166711,
#  'Loss/localization_loss': 0.020631487,
#  'Loss/regularization_loss': 0.14615735,
#  'Loss/total_loss': 0.20845595,
#  'learning_rate': 0.07990056}
# I0210 12:20:22.350352 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.04166711,
#  'Loss/localization_loss': 0.020631487,
#  'Loss/regularization_loss': 0.14615735,
#  'Loss/total_loss': 0.20845595,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.588s
# I0210 12:21:21.165519 140265946711872 model_lib_v2.py:705] Step 2200 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.04144553,
#  'Loss/localization_loss': 0.0149953505,
#  'Loss/regularization_loss': 0.14541663,
#  'Loss/total_loss': 0.2018575,
#  'learning_rate': 0.07988167}
# I0210 12:21:21.165904 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.04144553,
#  'Loss/localization_loss': 0.0149953505,
#  'Loss/regularization_loss': 0.14541663,
#  'Loss/total_loss': 0.2018575,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.620s
# I0210 12:22:23.151823 140265946711872 model_lib_v2.py:705] Step 2300 per-step time 0.620s
# INFO:tensorflow:{'Loss/classification_loss': 0.06887834,
#  'Loss/localization_loss': 0.025017586,
#  'Loss/regularization_loss': 0.14468302,
#  'Loss/total_loss': 0.23857895,
#  'learning_rate': 0.07986114}
# I0210 12:22:23.152227 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.06887834,
#  'Loss/localization_loss': 0.025017586,
#  'Loss/regularization_loss': 0.14468302,
#  'Loss/total_loss': 0.23857895,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.526s
# I0210 12:23:15.711891 140265946711872 model_lib_v2.py:705] Step 2400 per-step time 0.526s
# INFO:tensorflow:{'Loss/classification_loss': 0.07095076,
#  'Loss/localization_loss': 0.024898052,
#  'Loss/regularization_loss': 0.14395516,
#  'Loss/total_loss': 0.23980397,
#  'learning_rate': 0.07983897}
# I0210 12:23:15.712298 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.07095076,
#  'Loss/localization_loss': 0.024898052,
#  'Loss/regularization_loss': 0.14395516,
#  'Loss/total_loss': 0.23980397,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.597s
# I0210 12:24:15.445739 140265946711872 model_lib_v2.py:705] Step 2500 per-step time 0.597s
# INFO:tensorflow:{'Loss/classification_loss': 0.070619866,
#  'Loss/localization_loss': 0.029482527,
#  'Loss/regularization_loss': 0.14322829,
#  'Loss/total_loss': 0.24333069,
#  'learning_rate': 0.079815164}
# I0210 12:24:15.446111 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.070619866,
#  'Loss/localization_loss': 0.029482527,
#  'Loss/regularization_loss': 0.14322829,
#  'Loss/total_loss': 0.24333069,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.511s
# I0210 12:25:06.591697 140265946711872 model_lib_v2.py:705] Step 2600 per-step time 0.511s
# INFO:tensorflow:{'Loss/classification_loss': 0.06508883,
#  'Loss/localization_loss': 0.02835126,
#  'Loss/regularization_loss': 0.14244914,
#  'Loss/total_loss': 0.23588923,
#  'learning_rate': 0.07978972}
# I0210 12:25:06.592136 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.06508883,
#  'Loss/localization_loss': 0.02835126,
#  'Loss/regularization_loss': 0.14244914,
#  'Loss/total_loss': 0.23588923,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.613s
# I0210 12:26:07.905726 140265946711872 model_lib_v2.py:705] Step 2700 per-step time 0.613s
# INFO:tensorflow:{'Loss/classification_loss': 0.0889531,
#  'Loss/localization_loss': 0.015724469,
#  'Loss/regularization_loss': 0.14170405,
#  'Loss/total_loss': 0.24638163,
#  'learning_rate': 0.07976264}
# I0210 12:26:07.906152 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.0889531,
#  'Loss/localization_loss': 0.015724469,
#  'Loss/regularization_loss': 0.14170405,
#  'Loss/total_loss': 0.24638163,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.555s
# I0210 12:27:03.358076 140265946711872 model_lib_v2.py:705] Step 2800 per-step time 0.555s
# INFO:tensorflow:{'Loss/classification_loss': 0.07551244,
#  'Loss/localization_loss': 0.027641336,
#  'Loss/regularization_loss': 0.14094809,
#  'Loss/total_loss': 0.24410185,
#  'learning_rate': 0.07973392}
# I0210 12:27:03.358463 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.07551244,
#  'Loss/localization_loss': 0.027641336,
#  'Loss/regularization_loss': 0.14094809,
#  'Loss/total_loss': 0.24410185,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.546s
# I0210 12:27:57.957376 140265946711872 model_lib_v2.py:705] Step 2900 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.08768886,
#  'Loss/localization_loss': 0.016146803,
#  'Loss/regularization_loss': 0.14019993,
#  'Loss/total_loss': 0.2440356,
#  'learning_rate': 0.07970358}
# I0210 12:27:57.957910 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.08768886,
#  'Loss/localization_loss': 0.016146803,
#  'Loss/regularization_loss': 0.14019993,
#  'Loss/total_loss': 0.2440356,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.547s
# I0210 12:28:52.681142 140265946711872 model_lib_v2.py:705] Step 3000 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.053681467,
#  'Loss/localization_loss': 0.018491205,
#  'Loss/regularization_loss': 0.1394551,
#  'Loss/total_loss': 0.21162777,
#  'learning_rate': 0.0796716}
# I0210 12:28:52.681590 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.053681467,
#  'Loss/localization_loss': 0.018491205,
#  'Loss/regularization_loss': 0.1394551,
#  'Loss/total_loss': 0.21162777,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.633s
# I0210 12:29:55.962907 140265946711872 model_lib_v2.py:705] Step 3100 per-step time 0.633s
# INFO:tensorflow:{'Loss/classification_loss': 0.065333515,
#  'Loss/localization_loss': 0.02187825,
#  'Loss/regularization_loss': 0.13869947,
#  'Loss/total_loss': 0.22591123,
#  'learning_rate': 0.07963799}
# I0210 12:29:55.963316 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.065333515,
#  'Loss/localization_loss': 0.02187825,
#  'Loss/regularization_loss': 0.13869947,
#  'Loss/total_loss': 0.22591123,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.570s
# I0210 12:30:52.972365 140265946711872 model_lib_v2.py:705] Step 3200 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.04118295,
#  'Loss/localization_loss': 0.016560689,
#  'Loss/regularization_loss': 0.13796979,
#  'Loss/total_loss': 0.19571343,
#  'learning_rate': 0.07960275}
# I0210 12:30:52.972794 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.04118295,
#  'Loss/localization_loss': 0.016560689,
#  'Loss/regularization_loss': 0.13796979,
#  'Loss/total_loss': 0.19571343,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.562s
# I0210 12:31:49.133038 140265946711872 model_lib_v2.py:705] Step 3300 per-step time 0.562s
# INFO:tensorflow:{'Loss/classification_loss': 0.044802263,
#  'Loss/localization_loss': 0.019907199,
#  'Loss/regularization_loss': 0.1372263,
#  'Loss/total_loss': 0.20193577,
#  'learning_rate': 0.07956588}
# I0210 12:31:49.133409 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.044802263,
#  'Loss/localization_loss': 0.019907199,
#  'Loss/regularization_loss': 0.1372263,
#  'Loss/total_loss': 0.20193577,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.557s
# I0210 12:32:44.824844 140265946711872 model_lib_v2.py:705] Step 3400 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.048756678,
#  'Loss/localization_loss': 0.014722487,
#  'Loss/regularization_loss': 0.13653487,
#  'Loss/total_loss': 0.20001402,
#  'learning_rate': 0.079527386}
# I0210 12:32:44.825248 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.048756678,
#  'Loss/localization_loss': 0.014722487,
#  'Loss/regularization_loss': 0.13653487,
#  'Loss/total_loss': 0.20001402,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.537s
# I0210 12:33:38.532254 140265946711872 model_lib_v2.py:705] Step 3500 per-step time 0.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.04845192,
#  'Loss/localization_loss': 0.0108516775,
#  'Loss/regularization_loss': 0.1358224,
#  'Loss/total_loss': 0.195126,
#  'learning_rate': 0.07948727}
# I0210 12:33:38.532621 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.04845192,
#  'Loss/localization_loss': 0.0108516775,
#  'Loss/regularization_loss': 0.1358224,
#  'Loss/total_loss': 0.195126,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.577s
# I0210 12:34:36.251986 140265946711872 model_lib_v2.py:705] Step 3600 per-step time 0.577s
# INFO:tensorflow:{'Loss/classification_loss': 0.043614533,
#  'Loss/localization_loss': 0.017783666,
#  'Loss/regularization_loss': 0.13513973,
#  'Loss/total_loss': 0.19653794,
#  'learning_rate': 0.079445526}
# I0210 12:34:36.252362 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.043614533,
#  'Loss/localization_loss': 0.017783666,
#  'Loss/regularization_loss': 0.13513973,
#  'Loss/total_loss': 0.19653794,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.490s
# I0210 12:35:25.241896 140265946711872 model_lib_v2.py:705] Step 3700 per-step time 0.490s
# INFO:tensorflow:{'Loss/classification_loss': 0.038898084,
#  'Loss/localization_loss': 0.0098085655,
#  'Loss/regularization_loss': 0.13442944,
#  'Loss/total_loss': 0.18313609,
#  'learning_rate': 0.07940216}
# I0210 12:35:25.242278 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.038898084,
#  'Loss/localization_loss': 0.0098085655,
#  'Loss/regularization_loss': 0.13442944,
#  'Loss/total_loss': 0.18313609,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.564s
# I0210 12:36:21.669936 140265946711872 model_lib_v2.py:705] Step 3800 per-step time 0.564s
# INFO:tensorflow:{'Loss/classification_loss': 0.06465338,
#  'Loss/localization_loss': 0.01666871,
#  'Loss/regularization_loss': 0.1337413,
#  'Loss/total_loss': 0.2150634,
#  'learning_rate': 0.079357184}
# I0210 12:36:21.672141 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.06465338,
#  'Loss/localization_loss': 0.01666871,
#  'Loss/regularization_loss': 0.1337413,
#  'Loss/total_loss': 0.2150634,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.541s
# I0210 12:37:15.778803 140265946711872 model_lib_v2.py:705] Step 3900 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.12690125,
#  'Loss/localization_loss': 0.019373072,
#  'Loss/regularization_loss': 0.1330428,
#  'Loss/total_loss': 0.27931714,
#  'learning_rate': 0.07931058}
# I0210 12:37:15.779201 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.12690125,
#  'Loss/localization_loss': 0.019373072,
#  'Loss/regularization_loss': 0.1330428,
#  'Loss/total_loss': 0.27931714,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.550s
# I0210 12:38:10.789192 140265946711872 model_lib_v2.py:705] Step 4000 per-step time 0.550s
# INFO:tensorflow:{'Loss/classification_loss': 0.07301292,
#  'Loss/localization_loss': 0.013607533,
#  'Loss/regularization_loss': 0.13234098,
#  'Loss/total_loss': 0.21896143,
#  'learning_rate': 0.07926236}
# I0210 12:38:10.789741 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.07301292,
#  'Loss/localization_loss': 0.013607533,
#  'Loss/regularization_loss': 0.13234098,
#  'Loss/total_loss': 0.21896143,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.553s
# I0210 12:39:06.095859 140265946711872 model_lib_v2.py:705] Step 4100 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.033865586,
#  'Loss/localization_loss': 0.016311407,
#  'Loss/regularization_loss': 0.13165277,
#  'Loss/total_loss': 0.18182977,
#  'learning_rate': 0.07921253}
# I0210 12:39:06.096584 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.033865586,
#  'Loss/localization_loss': 0.016311407,
#  'Loss/regularization_loss': 0.13165277,
#  'Loss/total_loss': 0.18182977,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.625s
# I0210 12:40:08.596275 140265946711872 model_lib_v2.py:705] Step 4200 per-step time 0.625s
# INFO:tensorflow:{'Loss/classification_loss': 0.037663024,
#  'Loss/localization_loss': 0.007701161,
#  'Loss/regularization_loss': 0.130938,
#  'Loss/total_loss': 0.17630218,
#  'learning_rate': 0.07916109}
# I0210 12:40:08.596751 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.037663024,
#  'Loss/localization_loss': 0.007701161,
#  'Loss/regularization_loss': 0.130938,
#  'Loss/total_loss': 0.17630218,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.559s
# I0210 12:41:04.455082 140265946711872 model_lib_v2.py:705] Step 4300 per-step time 0.559s
# INFO:tensorflow:{'Loss/classification_loss': 0.06836207,
#  'Loss/localization_loss': 0.016298173,
#  'Loss/regularization_loss': 0.13024029,
#  'Loss/total_loss': 0.21490054,
#  'learning_rate': 0.07910804}
# I0210 12:41:04.455455 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.06836207,
#  'Loss/localization_loss': 0.016298173,
#  'Loss/regularization_loss': 0.13024029,
#  'Loss/total_loss': 0.21490054,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.566s
# I0210 12:42:01.061844 140265946711872 model_lib_v2.py:705] Step 4400 per-step time 0.566s
# INFO:tensorflow:{'Loss/classification_loss': 0.055142585,
#  'Loss/localization_loss': 0.013010166,
#  'Loss/regularization_loss': 0.12960668,
#  'Loss/total_loss': 0.19775942,
#  'learning_rate': 0.07905338}
# I0210 12:42:01.062244 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.055142585,
#  'Loss/localization_loss': 0.013010166,
#  'Loss/regularization_loss': 0.12960668,
#  'Loss/total_loss': 0.19775942,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.559s
# I0210 12:42:56.999414 140265946711872 model_lib_v2.py:705] Step 4500 per-step time 0.559s
# INFO:tensorflow:{'Loss/classification_loss': 0.043853927,
#  'Loss/localization_loss': 0.019323418,
#  'Loss/regularization_loss': 0.12892067,
#  'Loss/total_loss': 0.19209802,
#  'learning_rate': 0.07899711}
# I0210 12:42:56.999989 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.043853927,
#  'Loss/localization_loss': 0.019323418,
#  'Loss/regularization_loss': 0.12892067,
#  'Loss/total_loss': 0.19209802,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.549s
# I0210 12:43:51.854686 140265946711872 model_lib_v2.py:705] Step 4600 per-step time 0.549s
# INFO:tensorflow:{'Loss/classification_loss': 0.033072013,
#  'Loss/localization_loss': 0.013191413,
#  'Loss/regularization_loss': 0.1282466,
#  'Loss/total_loss': 0.17451003,
#  'learning_rate': 0.078939244}
# I0210 12:43:51.855068 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.033072013,
#  'Loss/localization_loss': 0.013191413,
#  'Loss/regularization_loss': 0.1282466,
#  'Loss/total_loss': 0.17451003,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.580s
# I0210 12:44:49.866421 140265946711872 model_lib_v2.py:705] Step 4700 per-step time 0.580s
# INFO:tensorflow:{'Loss/classification_loss': 0.055252273,
#  'Loss/localization_loss': 0.013894781,
#  'Loss/regularization_loss': 0.12755622,
#  'Loss/total_loss': 0.19670327,
#  'learning_rate': 0.07887978}
# I0210 12:44:49.869993 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.055252273,
#  'Loss/localization_loss': 0.013894781,
#  'Loss/regularization_loss': 0.12755622,
#  'Loss/total_loss': 0.19670327,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.539s
# I0210 12:45:43.719527 140265946711872 model_lib_v2.py:705] Step 4800 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.04800502,
#  'Loss/localization_loss': 0.015478486,
#  'Loss/regularization_loss': 0.12686503,
#  'Loss/total_loss': 0.19034854,
#  'learning_rate': 0.07881871}
# I0210 12:45:43.719875 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.04800502,
#  'Loss/localization_loss': 0.015478486,
#  'Loss/regularization_loss': 0.12686503,
#  'Loss/total_loss': 0.19034854,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.562s
# I0210 12:46:39.955621 140265946711872 model_lib_v2.py:705] Step 4900 per-step time 0.562s
# INFO:tensorflow:{'Loss/classification_loss': 0.06790481,
#  'Loss/localization_loss': 0.015018539,
#  'Loss/regularization_loss': 0.12619159,
#  'Loss/total_loss': 0.20911494,
#  'learning_rate': 0.07875605}
# I0210 12:46:39.956080 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.06790481,
#  'Loss/localization_loss': 0.015018539,
#  'Loss/regularization_loss': 0.12619159,
#  'Loss/total_loss': 0.20911494,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.568s
# I0210 12:47:36.800465 140265946711872 model_lib_v2.py:705] Step 5000 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.054555494,
#  'Loss/localization_loss': 0.008844285,
#  'Loss/regularization_loss': 0.12551095,
#  'Loss/total_loss': 0.18891072,
#  'learning_rate': 0.078691795}
# I0210 12:47:36.800827 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.054555494,
#  'Loss/localization_loss': 0.008844285,
#  'Loss/regularization_loss': 0.12551095,
#  'Loss/total_loss': 0.18891072,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.580s
# I0210 12:48:34.802107 140265946711872 model_lib_v2.py:705] Step 5100 per-step time 0.580s
# INFO:tensorflow:{'Loss/classification_loss': 0.04466607,
#  'Loss/localization_loss': 0.010896902,
#  'Loss/regularization_loss': 0.12486671,
#  'Loss/total_loss': 0.18042968,
#  'learning_rate': 0.07862595}
# I0210 12:48:34.802561 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.04466607,
#  'Loss/localization_loss': 0.010896902,
#  'Loss/regularization_loss': 0.12486671,
#  'Loss/total_loss': 0.18042968,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.520s
# I0210 12:49:26.803646 140265946711872 model_lib_v2.py:705] Step 5200 per-step time 0.520s
# INFO:tensorflow:{'Loss/classification_loss': 0.119709864,
#  'Loss/localization_loss': 0.019968977,
#  'Loss/regularization_loss': 0.12422234,
#  'Loss/total_loss': 0.26390117,
#  'learning_rate': 0.07855851}
# I0210 12:49:26.804011 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.119709864,
#  'Loss/localization_loss': 0.019968977,
#  'Loss/regularization_loss': 0.12422234,
#  'Loss/total_loss': 0.26390117,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.573s
# I0210 12:50:24.078783 140265946711872 model_lib_v2.py:705] Step 5300 per-step time 0.573s
# INFO:tensorflow:{'Loss/classification_loss': 0.056282997,
#  'Loss/localization_loss': 0.023652915,
#  'Loss/regularization_loss': 0.12358688,
#  'Loss/total_loss': 0.20352279,
#  'learning_rate': 0.07848949}
# I0210 12:50:24.079187 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.056282997,
#  'Loss/localization_loss': 0.023652915,
#  'Loss/regularization_loss': 0.12358688,
#  'Loss/total_loss': 0.20352279,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.532s
# I0210 12:51:17.285683 140265946711872 model_lib_v2.py:705] Step 5400 per-step time 0.532s
# INFO:tensorflow:{'Loss/classification_loss': 0.061005633,
#  'Loss/localization_loss': 0.014925849,
#  'Loss/regularization_loss': 0.12304757,
#  'Loss/total_loss': 0.19897905,
#  'learning_rate': 0.078418896}
# I0210 12:51:17.286056 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.061005633,
#  'Loss/localization_loss': 0.014925849,
#  'Loss/regularization_loss': 0.12304757,
#  'Loss/total_loss': 0.19897905,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.588s
# I0210 12:52:16.073026 140265946711872 model_lib_v2.py:705] Step 5500 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.10265684,
#  'Loss/localization_loss': 0.06840484,
#  'Loss/regularization_loss': 0.12443626,
#  'Loss/total_loss': 0.29549795,
#  'learning_rate': 0.078346714}
# I0210 12:52:16.073384 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.10265684,
#  'Loss/localization_loss': 0.06840484,
#  'Loss/regularization_loss': 0.12443626,
#  'Loss/total_loss': 0.29549795,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.533s
# I0210 12:53:09.360729 140265946711872 model_lib_v2.py:705] Step 5600 per-step time 0.533s
# INFO:tensorflow:{'Loss/classification_loss': 0.08705557,
#  'Loss/localization_loss': 0.022348175,
#  'Loss/regularization_loss': 0.1247415,
#  'Loss/total_loss': 0.23414525,
#  'learning_rate': 0.07827295}
# I0210 12:53:09.361121 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.08705557,
#  'Loss/localization_loss': 0.022348175,
#  'Loss/regularization_loss': 0.1247415,
#  'Loss/total_loss': 0.23414525,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.588s
# I0210 12:54:08.156864 140265946711872 model_lib_v2.py:705] Step 5700 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.07739781,
#  'Loss/localization_loss': 0.031403553,
#  'Loss/regularization_loss': 0.12579922,
#  'Loss/total_loss': 0.23460059,
#  'learning_rate': 0.07819763}
# I0210 12:54:08.157219 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.07739781,
#  'Loss/localization_loss': 0.031403553,
#  'Loss/regularization_loss': 0.12579922,
#  'Loss/total_loss': 0.23460059,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.603s
# I0210 12:55:08.439237 140265946711872 model_lib_v2.py:705] Step 5800 per-step time 0.603s
# INFO:tensorflow:{'Loss/classification_loss': 0.06845858,
#  'Loss/localization_loss': 0.018751744,
#  'Loss/regularization_loss': 0.12525085,
#  'Loss/total_loss': 0.21246117,
#  'learning_rate': 0.07812072}
# I0210 12:55:08.440201 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.06845858,
#  'Loss/localization_loss': 0.018751744,
#  'Loss/regularization_loss': 0.12525085,
#  'Loss/total_loss': 0.21246117,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.520s
# I0210 12:56:00.480706 140265946711872 model_lib_v2.py:705] Step 5900 per-step time 0.520s
# INFO:tensorflow:{'Loss/classification_loss': 0.046048872,
#  'Loss/localization_loss': 0.015334315,
#  'Loss/regularization_loss': 0.12460727,
#  'Loss/total_loss': 0.18599045,
#  'learning_rate': 0.078042254}
# I0210 12:56:00.481111 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.046048872,
#  'Loss/localization_loss': 0.015334315,
#  'Loss/regularization_loss': 0.12460727,
#  'Loss/total_loss': 0.18599045,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.578s
# I0210 12:56:58.290361 140265946711872 model_lib_v2.py:705] Step 6000 per-step time 0.578s
# INFO:tensorflow:{'Loss/classification_loss': 0.07107172,
#  'Loss/localization_loss': 0.018818175,
#  'Loss/regularization_loss': 0.12394159,
#  'Loss/total_loss': 0.21383148,
#  'learning_rate': 0.07796223}
# I0210 12:56:58.291390 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.07107172,
#  'Loss/localization_loss': 0.018818175,
#  'Loss/regularization_loss': 0.12394159,
#  'Loss/total_loss': 0.21383148,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.547s
# I0210 12:57:52.950016 140265946711872 model_lib_v2.py:705] Step 6100 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.057578042,
#  'Loss/localization_loss': 0.016776199,
#  'Loss/regularization_loss': 0.123312384,
#  'Loss/total_loss': 0.19766662,
#  'learning_rate': 0.077880636}
# I0210 12:57:52.950419 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.057578042,
#  'Loss/localization_loss': 0.016776199,
#  'Loss/regularization_loss': 0.123312384,
#  'Loss/total_loss': 0.19766662,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.604s
# I0210 12:58:53.342637 140265946711872 model_lib_v2.py:705] Step 6200 per-step time 0.604s
# ...
#  'Loss/localization_loss': 0.004639421,
#  'Loss/regularization_loss': 0.080436654,
#  'Loss/total_loss': 0.15090077,
#  'learning_rate': 0.064939596}
# INFO:tensorflow:Step 15100 per-step time 0.575s
# I0210 14:19:43.953340 140265946711872 model_lib_v2.py:705] Step 15100 per-step time 0.575s
# INFO:tensorflow:{'Loss/classification_loss': 0.050249368,
#  'Loss/localization_loss': 0.008589374,
#  'Loss/regularization_loss': 0.08009706,
#  'Loss/total_loss': 0.1389358,
#  'learning_rate': 0.06473857}
# I0210 14:19:43.953717 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.050249368,
#  'Loss/localization_loss': 0.008589374,
#  'Loss/regularization_loss': 0.08009706,
#  'Loss/total_loss': 0.1389358,
#  'learning_rate': 0.06473857}
# INFO:tensorflow:Step 15200 per-step time 0.532s
# I0210 14:20:37.197709 140265946711872 model_lib_v2.py:705] Step 15200 per-step time 0.532s
# INFO:tensorflow:{'Loss/classification_loss': 0.030354016,
#  'Loss/localization_loss': 0.0058586188,
#  'Loss/regularization_loss': 0.079771556,
#  'Loss/total_loss': 0.11598419,
#  'learning_rate': 0.06453654}
# I0210 14:20:37.198106 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.030354016,
#  'Loss/localization_loss': 0.0058586188,
#  'Loss/regularization_loss': 0.079771556,
#  'Loss/total_loss': 0.11598419,
#  'learning_rate': 0.06453654}
# INFO:tensorflow:Step 15300 per-step time 0.576s
# I0210 14:21:34.845319 140265946711872 model_lib_v2.py:705] Step 15300 per-step time 0.576s
# INFO:tensorflow:{'Loss/classification_loss': 0.032058507,
#  'Loss/localization_loss': 0.005297323,
#  'Loss/regularization_loss': 0.079434045,
#  'Loss/total_loss': 0.11678988,
#  'learning_rate': 0.06433349}
# I0210 14:21:34.845828 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.032058507,
#  'Loss/localization_loss': 0.005297323,
#  'Loss/regularization_loss': 0.079434045,
#  'Loss/total_loss': 0.11678988,
#  'learning_rate': 0.06433349}
# INFO:tensorflow:Step 15400 per-step time 0.467s
# I0210 14:22:21.579963 140265946711872 model_lib_v2.py:705] Step 15400 per-step time 0.467s
# INFO:tensorflow:{'Loss/classification_loss': 0.13093154,
#  'Loss/localization_loss': 0.01121163,
#  'Loss/regularization_loss': 0.07909529,
#  'Loss/total_loss': 0.22123846,
#  'learning_rate': 0.06412946}
# I0210 14:22:21.580351 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.13093154,
#  'Loss/localization_loss': 0.01121163,
#  'Loss/regularization_loss': 0.07909529,
#  'Loss/total_loss': 0.22123846,
#  'learning_rate': 0.06412946}
# INFO:tensorflow:Step 15500 per-step time 0.554s
# I0210 14:23:16.935664 140265946711872 model_lib_v2.py:705] Step 15500 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.051138252,
#  'Loss/localization_loss': 0.003914151,
#  'Loss/regularization_loss': 0.07876723,
#  'Loss/total_loss': 0.13381964,
#  'learning_rate': 0.063924424}
# I0210 14:23:16.936028 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.051138252,
#  'Loss/localization_loss': 0.003914151,
#  'Loss/regularization_loss': 0.07876723,
#  'Loss/total_loss': 0.13381964,
#  'learning_rate': 0.063924424}
# INFO:tensorflow:Step 15600 per-step time 0.523s
# I0210 14:24:09.235282 140265946711872 model_lib_v2.py:705] Step 15600 per-step time 0.523s
# INFO:tensorflow:{'Loss/classification_loss': 0.030418666,
#  'Loss/localization_loss': 0.0056085037,
#  'Loss/regularization_loss': 0.07842609,
#  'Loss/total_loss': 0.11445326,
#  'learning_rate': 0.0637184}
# I0210 14:24:09.235661 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.030418666,
#  'Loss/localization_loss': 0.0056085037,
#  'Loss/regularization_loss': 0.07842609,
#  'Loss/total_loss': 0.11445326,
#  'learning_rate': 0.0637184}
# INFO:tensorflow:Step 15700 per-step time 0.513s
# I0210 14:25:00.561170 140265946711872 model_lib_v2.py:705] Step 15700 per-step time 0.513s
# INFO:tensorflow:{'Loss/classification_loss': 0.019205619,
#  'Loss/localization_loss': 0.0057096938,
#  'Loss/regularization_loss': 0.07809851,
#  'Loss/total_loss': 0.10301383,
#  'learning_rate': 0.06351141}
# I0210 14:25:00.561687 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.019205619,
#  'Loss/localization_loss': 0.0057096938,
#  'Loss/regularization_loss': 0.07809851,
#  'Loss/total_loss': 0.10301383,
#  'learning_rate': 0.06351141}
# INFO:tensorflow:Step 15800 per-step time 0.539s
# I0210 14:25:54.474475 140265946711872 model_lib_v2.py:705] Step 15800 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.020634653,
#  'Loss/localization_loss': 0.0063668033,
#  'Loss/regularization_loss': 0.07777285,
#  'Loss/total_loss': 0.104774304,
#  'learning_rate': 0.06330345}
# I0210 14:25:54.474871 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.020634653,
#  'Loss/localization_loss': 0.0063668033,
#  'Loss/regularization_loss': 0.07777285,
#  'Loss/total_loss': 0.104774304,
#  'learning_rate': 0.06330345}
# INFO:tensorflow:Step 15900 per-step time 0.568s
# I0210 14:26:51.339985 140265946711872 model_lib_v2.py:705] Step 15900 per-step time 0.568s
# INFO:tensorflow:{'Loss/classification_loss': 0.091252856,
#  'Loss/localization_loss': 0.007826952,
#  'Loss/regularization_loss': 0.07744947,
#  'Loss/total_loss': 0.17652929,
#  'learning_rate': 0.06309453}
# I0210 14:26:51.340373 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.091252856,
#  'Loss/localization_loss': 0.007826952,
#  'Loss/regularization_loss': 0.07744947,
#  'Loss/total_loss': 0.17652929,
#  'learning_rate': 0.06309453}
# INFO:tensorflow:Step 16000 per-step time 0.529s
# I0210 14:27:44.182954 140265946711872 model_lib_v2.py:705] Step 16000 per-step time 0.529s
# INFO:tensorflow:{'Loss/classification_loss': 0.026067756,
#  'Loss/localization_loss': 0.006599442,
#  'Loss/regularization_loss': 0.07714648,
#  'Loss/total_loss': 0.109813675,
#  'learning_rate': 0.062884666}
# I0210 14:27:44.183420 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.026067756,
#  'Loss/localization_loss': 0.006599442,
#  'Loss/regularization_loss': 0.07714648,
#  'Loss/total_loss': 0.109813675,
#  'learning_rate': 0.062884666}
# INFO:tensorflow:Step 16100 per-step time 0.503s
# I0210 14:28:34.506903 140265946711872 model_lib_v2.py:705] Step 16100 per-step time 0.503s
# INFO:tensorflow:{'Loss/classification_loss': 0.024261905,
#  'Loss/localization_loss': 0.005225906,
#  'Loss/regularization_loss': 0.07681582,
#  'Loss/total_loss': 0.10630363,
#  'learning_rate': 0.06267385}
# I0210 14:28:34.507265 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.024261905,
#  'Loss/localization_loss': 0.005225906,
#  'Loss/regularization_loss': 0.07681582,
#  'Loss/total_loss': 0.10630363,
#  'learning_rate': 0.06267385}
# INFO:tensorflow:Step 16200 per-step time 0.569s
# I0210 14:29:31.384191 140265946711872 model_lib_v2.py:705] Step 16200 per-step time 0.569s
# INFO:tensorflow:{'Loss/classification_loss': 0.021253567,
#  'Loss/localization_loss': 0.005692887,
#  'Loss/regularization_loss': 0.07649851,
#  'Loss/total_loss': 0.10344496,
#  'learning_rate': 0.062462118}
# I0210 14:29:31.384582 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.021253567,
#  'Loss/localization_loss': 0.005692887,
#  'Loss/regularization_loss': 0.07649851,
#  'Loss/total_loss': 0.10344496,
#  'learning_rate': 0.062462118}
# INFO:tensorflow:Step 16300 per-step time 0.491s
# I0210 14:30:20.433964 140265946711872 model_lib_v2.py:705] Step 16300 per-step time 0.491s
# INFO:tensorflow:{'Loss/classification_loss': 0.027381152,
#  'Loss/localization_loss': 0.006043232,
#  'Loss/regularization_loss': 0.076165505,
#  'Loss/total_loss': 0.10958989,
#  'learning_rate': 0.06224946}
# I0210 14:30:20.434403 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.027381152,
#  'Loss/localization_loss': 0.006043232,
#  'Loss/regularization_loss': 0.076165505,
#  'Loss/total_loss': 0.10958989,
#  'learning_rate': 0.06224946}
# INFO:tensorflow:Step 16400 per-step time 0.594s
# I0210 14:31:19.892992 140265946711872 model_lib_v2.py:705] Step 16400 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.045561437,
#  'Loss/localization_loss': 0.0058189286,
#  'Loss/regularization_loss': 0.07584936,
#  'Loss/total_loss': 0.12722972,
#  'learning_rate': 0.062035877}
# I0210 14:31:19.893338 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.045561437,
#  'Loss/localization_loss': 0.0058189286,
#  'Loss/regularization_loss': 0.07584936,
#  'Loss/total_loss': 0.12722972,
#  'learning_rate': 0.062035877}
# INFO:tensorflow:Step 16500 per-step time 0.521s
# I0210 14:32:11.972249 140265946711872 model_lib_v2.py:705] Step 16500 per-step time 0.521s
# INFO:tensorflow:{'Loss/classification_loss': 0.04835148,
#  'Loss/localization_loss': 0.0050846753,
#  'Loss/regularization_loss': 0.07553924,
#  'Loss/total_loss': 0.12897539,
#  'learning_rate': 0.061821394}
# I0210 14:32:11.972595 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.04835148,
#  'Loss/localization_loss': 0.0050846753,
#  'Loss/regularization_loss': 0.07553924,
#  'Loss/total_loss': 0.12897539,
#  'learning_rate': 0.061821394}
# INFO:tensorflow:Step 16600 per-step time 0.505s
# I0210 14:33:02.464840 140265946711872 model_lib_v2.py:705] Step 16600 per-step time 0.505s
# INFO:tensorflow:{'Loss/classification_loss': 0.025400408,
#  'Loss/localization_loss': 0.0070050275,
#  'Loss/regularization_loss': 0.07523449,
#  'Loss/total_loss': 0.10763992,
#  'learning_rate': 0.061606016}
# I0210 14:33:02.465197 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.025400408,
#  'Loss/localization_loss': 0.0070050275,
#  'Loss/regularization_loss': 0.07523449,
#  'Loss/total_loss': 0.10763992,
#  'learning_rate': 0.061606016}
# INFO:tensorflow:Step 16700 per-step time 0.544s
# I0210 14:33:56.850170 140265946711872 model_lib_v2.py:705] Step 16700 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.029729724,
#  'Loss/localization_loss': 0.006129173,
#  'Loss/regularization_loss': 0.07492178,
#  'Loss/total_loss': 0.11078067,
#  'learning_rate': 0.06138974}
# I0210 14:33:56.850524 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.029729724,
#  'Loss/localization_loss': 0.006129173,
#  'Loss/regularization_loss': 0.07492178,
#  'Loss/total_loss': 0.11078067,
#  'learning_rate': 0.06138974}
# INFO:tensorflow:Step 16800 per-step time 0.588s
# I0210 14:34:55.636200 140265946711872 model_lib_v2.py:705] Step 16800 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.045597706,
#  'Loss/localization_loss': 0.006106721,
#  'Loss/regularization_loss': 0.074618675,
#  'Loss/total_loss': 0.1263231,
#  'learning_rate': 0.061172597}
# I0210 14:34:55.636557 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.045597706,
#  'Loss/localization_loss': 0.006106721,
#  'Loss/regularization_loss': 0.074618675,
#  'Loss/total_loss': 0.1263231,
#  'learning_rate': 0.061172597}
# INFO:tensorflow:Step 16900 per-step time 0.555s
# I0210 14:35:51.180782 140265946711872 model_lib_v2.py:705] Step 16900 per-step time 0.555s
# INFO:tensorflow:{'Loss/classification_loss': 0.022405831,
#  'Loss/localization_loss': 0.0030102371,
#  'Loss/regularization_loss': 0.074309416,
#  'Loss/total_loss': 0.099725485,
#  'learning_rate': 0.06095458}
# I0210 14:35:51.183924 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.022405831,
#  'Loss/localization_loss': 0.0030102371,
#  'Loss/regularization_loss': 0.074309416,
#  'Loss/total_loss': 0.099725485,
#  'learning_rate': 0.06095458}
# INFO:tensorflow:Step 17000 per-step time 0.552s
# I0210 14:36:46.412572 140265946711872 model_lib_v2.py:705] Step 17000 per-step time 0.552s
# INFO:tensorflow:{'Loss/classification_loss': 0.036314983,
#  'Loss/localization_loss': 0.009013464,
#  'Loss/regularization_loss': 0.074010365,
#  'Loss/total_loss': 0.11933881,
#  'learning_rate': 0.060735703}
# I0210 14:36:46.412925 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.036314983,
#  'Loss/localization_loss': 0.009013464,
#  'Loss/regularization_loss': 0.074010365,
#  'Loss/total_loss': 0.11933881,
#  'learning_rate': 0.060735703}
# INFO:tensorflow:Step 17100 per-step time 0.519s
# I0210 14:37:38.321722 140265946711872 model_lib_v2.py:705] Step 17100 per-step time 0.519s
# INFO:tensorflow:{'Loss/classification_loss': 0.026750306,
#  'Loss/localization_loss': 0.004814789,
#  'Loss/regularization_loss': 0.0737251,
#  'Loss/total_loss': 0.10529019,
#  'learning_rate': 0.060515966}
# I0210 14:37:38.323868 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.026750306,
#  'Loss/localization_loss': 0.004814789,
#  'Loss/regularization_loss': 0.0737251,
#  'Loss/total_loss': 0.10529019,
#  'learning_rate': 0.060515966}
# INFO:tensorflow:Step 17200 per-step time 0.537s
# I0210 14:38:31.994955 140265946711872 model_lib_v2.py:705] Step 17200 per-step time 0.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.03939808,
#  'Loss/localization_loss': 0.011860977,
#  'Loss/regularization_loss': 0.07342529,
#  'Loss/total_loss': 0.12468435,
#  'learning_rate': 0.060295396}
# I0210 14:38:31.995312 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.03939808,
#  'Loss/localization_loss': 0.011860977,
#  'Loss/regularization_loss': 0.07342529,
#  'Loss/total_loss': 0.12468435,
#  'learning_rate': 0.060295396}
# INFO:tensorflow:Step 17300 per-step time 0.548s
# I0210 14:39:26.777066 140265946711872 model_lib_v2.py:705] Step 17300 per-step time 0.548s
# INFO:tensorflow:{'Loss/classification_loss': 0.043074768,
#  'Loss/localization_loss': 0.007082753,
#  'Loss/regularization_loss': 0.07313531,
#  'Loss/total_loss': 0.12329283,
#  'learning_rate': 0.060073983}
# I0210 14:39:26.777621 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.043074768,
#  'Loss/localization_loss': 0.007082753,
#  'Loss/regularization_loss': 0.07313531,
#  'Loss/total_loss': 0.12329283,
#  'learning_rate': 0.060073983}
# INFO:tensorflow:Step 17400 per-step time 0.542s
# I0210 14:40:20.936186 140265946711872 model_lib_v2.py:705] Step 17400 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.028057694,
#  'Loss/localization_loss': 0.0034415114,
#  'Loss/regularization_loss': 0.07286035,
#  'Loss/total_loss': 0.10435956,
#  'learning_rate': 0.05985175}
# I0210 14:40:20.936872 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.028057694,
#  'Loss/localization_loss': 0.0034415114,
#  'Loss/regularization_loss': 0.07286035,
#  'Loss/total_loss': 0.10435956,
#  'learning_rate': 0.05985175}
# INFO:tensorflow:Step 17500 per-step time 0.544s
# I0210 14:41:15.344826 140265946711872 model_lib_v2.py:705] Step 17500 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.037725344,
#  'Loss/localization_loss': 0.0044337483,
#  'Loss/regularization_loss': 0.07257697,
#  'Loss/total_loss': 0.114736065,
#  'learning_rate': 0.0596287}
# I0210 14:41:15.345168 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.037725344,
#  'Loss/localization_loss': 0.0044337483,
#  'Loss/regularization_loss': 0.07257697,
#  'Loss/total_loss': 0.114736065,
#  'learning_rate': 0.0596287}
# INFO:tensorflow:Step 17600 per-step time 0.501s
# I0210 14:42:05.454721 140265946711872 model_lib_v2.py:705] Step 17600 per-step time 0.501s
# INFO:tensorflow:{'Loss/classification_loss': 0.017390778,
#  'Loss/localization_loss': 0.0035120863,
#  'Loss/regularization_loss': 0.0722824,
#  'Loss/total_loss': 0.09318527,
#  'learning_rate': 0.05940484}
# I0210 14:42:05.455078 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.017390778,
#  'Loss/localization_loss': 0.0035120863,
#  'Loss/regularization_loss': 0.0722824,
#  'Loss/total_loss': 0.09318527,
#  'learning_rate': 0.05940484}
# INFO:tensorflow:Step 17700 per-step time 0.521s
# I0210 14:42:57.513195 140265946711872 model_lib_v2.py:705] Step 17700 per-step time 0.521s
# INFO:tensorflow:{'Loss/classification_loss': 0.020326488,
#  'Loss/localization_loss': 0.007223886,
#  'Loss/regularization_loss': 0.07199662,
#  'Loss/total_loss': 0.099547,
#  'learning_rate': 0.059180185}
# I0210 14:42:57.513622 140265946711872 model_lib_v2.py:708] {'Loss/classification_loss': 0.020326488,
#  'Loss/localization_loss': 0.007223886,
#  'Loss/regularization_loss': 0.07199662,
#  'Loss/total_loss': 0.099547,
#  'learning_rate': 0.059180185}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet

# %%
# !{command}
# Out:
# 2023-02-09 18:53:40.205229: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-09 18:53:40.205352: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-09 18:53:40.205377: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0209 18:53:44.507950 139945390516032 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0209 18:53:44.508186 139945390516032 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0209 18:53:44.508279 139945390516032 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0209 18:53:44.508362 139945390516032 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0209 18:53:44.508483 139945390516032 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2023-02-09 18:53:45.417183: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# I0209 18:53:45.467950 139945390516032 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# I0209 18:53:45.468180 139945390516032 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0209 18:53:45.468271 139945390516032 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0209 18:53:45.468335 139945390516032 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0209 18:53:45.471773 139945390516032 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0209 18:53:45.489297 139945390516032 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0209 18:53:46.033482 139945390516032 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0209 18:53:48.853894 139945390516032 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0209 18:53:49.844728 139945390516032 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# I0209 18:53:52.062766 139945390516032 checkpoint_utils.py:140] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# INFO:tensorflow:Found new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet/ckpt-3
# I0209 18:53:52.063602 139945390516032 checkpoint_utils.py:149] Found new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet/ckpt-3
# /usr/local/lib/python3.8/dist-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0209 18:54:20.899768 139945390516032 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0209 18:54:20.940609 139945390516032 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0209 18:54:21.391388 139945390516032 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Performing evaluation on 10 images.
# I0209 18:54:33.348304 139945390516032 coco_evaluation.py:293] Performing evaluation on 10 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0209 18:54:33.348673 139945390516032 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I0209 18:54:33.352303 139945390516032 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.695
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.695
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.710
# INFO:tensorflow:Eval metrics at step 2000
# I0209 18:54:33.462982 139945390516032 model_lib_v2.py:1015] Eval metrics at step 2000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.695149
# I0209 18:54:33.477885 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.695149
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 1.000000
# I0209 18:54:33.479758 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.850495
# I0209 18:54:33.481431 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.850495
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): -1.000000
# I0209 18:54:33.483058 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# I0209 18:54:33.484455 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.695149
# I0209 18:54:33.485861 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.695149
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.710000
# I0209 18:54:33.487457 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.710000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.710000
# I0209 18:54:33.488858 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.710000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.710000
# I0209 18:54:33.490233 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.710000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# I0209 18:54:33.491658 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# I0209 18:54:33.493043 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.710000
# I0209 18:54:33.494472 139945390516032 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.710000
# INFO:tensorflow:	+ Loss/localization_loss: 0.101346
# I0209 18:54:33.495724 139945390516032 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.101346
# INFO:tensorflow:	+ Loss/classification_loss: 0.172411
# I0209 18:54:33.496996 139945390516032 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.172411
# INFO:tensorflow:	+ Loss/regularization_loss: 0.145541
# I0209 18:54:33.498243 139945390516032 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.145541
# INFO:tensorflow:	+ Loss/total_loss: 0.419298
# I0209 18:54:33.499481 139945390516032 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.419298
# Traceback (most recent call last):
#   File "Tensorflow/models/research/object_detection/model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/platform/app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.8/dist-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.8/dist-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "Tensorflow/models/research/object_detection/model_main_tf2.py", line 81, in main
#     model_lib_v2.eval_continuously(
#   File "/usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py", line 1135, in eval_continuously
#     for latest_checkpoint in tf.train.checkpoints_iterator(
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 216, in checkpoints_iterator
#     time.sleep(time_to_next_eval)
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/loader.py", line 34, in _remove_file
#     os.remove(file_name)
# KeyboardInterrupt
# ^C

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'thanks5.jpeg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened():
    ret, frame = cap.read()
    image_np = np.array(frame)

    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)

    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))

    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet --output_directory=Tensorflow/workspace/models/my_ssd_mobnet/export

# %%
# !{command}
# Out:
# 2023-02-10 00:07:36.496478: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.8/dist-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-10 00:07:36.496660: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.8/dist-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-10 00:07:36.496679: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-10 00:07:39.816956: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0210 00:07:39.938043 140666643392320 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0210 00:07:40.025293 140666643392320 deprecation.py:623] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fef00576670>, because it is not built.
# W0210 00:08:09.625379 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fef00576670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7feeeb678970>, because it is not built.
# W0210 00:08:10.133314 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7feeeb678970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb50fe50>, because it is not built.
# W0210 00:08:10.133710 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb50fe50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb50fd30>, because it is not built.
# W0210 00:08:10.133882 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb50fd30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7feeeb50f6a0>, because it is not built.
# W0210 00:08:10.134006 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7feeeb50f6a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb50f820>, because it is not built.
# W0210 00:08:10.134143 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb50f820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb767760>, because it is not built.
# W0210 00:08:10.134263 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb767760>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7feeeb6d6be0>, because it is not built.
# W0210 00:08:10.134370 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7feeeb6d6be0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb6d6460>, because it is not built.
# W0210 00:08:10.134491 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb6d6460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb6d6310>, because it is not built.
# W0210 00:08:10.134618 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb6d6310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7feeeb4a1190>, because it is not built.
# W0210 00:08:10.134725 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7feeeb4a1190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb327100>, because it is not built.
# W0210 00:08:10.134825 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb327100>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb327790>, because it is not built.
# W0210 00:08:10.134921 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb327790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef001a3790>, because it is not built.
# W0210 00:08:10.135013 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef001a3790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb67b670>, because it is not built.
# W0210 00:08:10.135115 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb67b670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef00402130>, because it is not built.
# W0210 00:08:10.135217 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef00402130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef002359a0>, because it is not built.
# W0210 00:08:10.135345 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef002359a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef002393d0>, because it is not built.
# W0210 00:08:10.135473 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef002393d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb7a4ee0>, because it is not built.
# W0210 00:08:10.135595 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb7a4ee0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef003fffd0>, because it is not built.
# W0210 00:08:10.135704 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef003fffd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef003ffa00>, because it is not built.
# W0210 00:08:10.135803 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef003ffa00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb70b1c0>, because it is not built.
# W0210 00:08:10.135897 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb70b1c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb6f85b0>, because it is not built.
# W0210 00:08:10.135991 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb6f85b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb32b9a0>, because it is not built.
# W0210 00:08:10.136093 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb32b9a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb32b1c0>, because it is not built.
# W0210 00:08:10.136195 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb32b1c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef001a8640>, because it is not built.
# W0210 00:08:10.136291 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef001a8640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef001fc490>, because it is not built.
# W0210 00:08:10.136390 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef001fc490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef001cb160>, because it is not built.
# W0210 00:08:10.136507 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef001cb160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef001569d0>, because it is not built.
# W0210 00:08:10.136632 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef001569d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef0019b1c0>, because it is not built.
# W0210 00:08:10.136736 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef0019b1c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef0019cd90>, because it is not built.
# W0210 00:08:10.136831 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef0019cd90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef000de2e0>, because it is not built.
# W0210 00:08:10.136922 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef000de2e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef000de0a0>, because it is not built.
# W0210 00:08:10.137058 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef000de0a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef000ded30>, because it is not built.
# W0210 00:08:10.137177 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef000ded30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef000de0d0>, because it is not built.
# W0210 00:08:10.137277 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef000de0d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef001325b0>, because it is not built.
# W0210 00:08:10.137385 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef001325b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef00132370>, because it is not built.
# W0210 00:08:10.137522 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef00132370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb6446d0>, because it is not built.
# W0210 00:08:10.137641 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb6446d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb66d790>, because it is not built.
# W0210 00:08:10.137772 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb66d790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef000da280>, because it is not built.
# W0210 00:08:10.137872 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef000da280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef000dadf0>, because it is not built.
# W0210 00:08:10.137971 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef000dadf0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb2dfc70>, because it is not built.
# W0210 00:08:10.138075 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7feeeb2dfc70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb2dff40>, because it is not built.
# W0210 00:08:10.138177 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7feeeb2dff40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef00224c40>, because it is not built.
# W0210 00:08:10.144042 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fef00224c40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef00224430>, because it is not built.
# W0210 00:08:10.144290 140666643392320 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fef00224430>, because it is not built.
# W0210 00:08:38.935165 140666643392320 save.py:271] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# I0210 00:08:45.296659 140666643392320 builder_impl.py:797] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config
# I0210 00:08:46.981775 140666643392320 config_util.py:253] Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: jax>=0.3.16 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (0.3.25)
# Collecting packaging~=20.9
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 KB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (5.10.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (3.19.6)
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (1.15.0)
# Collecting tensorflow-decision-forests>=1.0.1
#   Downloading tensorflow_decision_forests-1.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 48.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: tensorflow<3,>=2.10.0 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (2.11.0)
# Collecting flax>=0.6.2
#   Downloading flax-0.6.5-py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 KB 18.2 MB/s eta 0:00:00
# Collecting tensorstore
#   Downloading tensorstore-0.1.31-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 85.5 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (5.4.1)
# Collecting jax>=0.3.16
#   Downloading jax-0.4.3.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 57.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting optax
#   Downloading optax-0.1.4-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.9/154.9 KB 15.6 MB/s eta 0:00:00
# Collecting orbax
#   Downloading orbax-0.1.1-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 KB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: msgpack in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (1.0.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (3.2.2)
# Collecting rich>=11.1
#   Downloading rich-13.3.1-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 KB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (1.21.6)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (4.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib_resources>=5.9.0->tensorflowjs) (3.12.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.8/dist-packages (from jax>=0.3.16->tensorflowjs) (3.3.0)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.8/dist-packages (from jax>=0.3.16->tensorflowjs) (1.7.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging~=20.9->tensorflowjs) (2.4.7)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (23.1.21)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.11.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (57.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (15.0.6.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.51.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.30.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.11.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from tensorflow-decision-forests>=1.0.1->tensorflowjs) (0.38.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from tensorflow-decision-forests>=1.0.1->tensorflowjs) (1.3.5)
# Collecting wurlitzer
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Collecting pygments<3.0.0,>=2.14.0
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.6 MB/s eta 0:00:00
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (2.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax>=0.6.2->tensorflowjs) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax>=0.6.2->tensorflowjs) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax>=0.6.2->tensorflowjs) (2.8.2)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.8/dist-packages (from optax->flax>=0.6.2->tensorflowjs) (0.3.25+cuda11.cudnn805)
# Collecting chex>=0.1.5
#   Downloading chex-0.1.6-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 KB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: etils in /usr/local/lib/python3.8/dist-packages (from orbax->flax>=0.6.2->tensorflowjs) (1.0.0)
# Collecting cached_property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->tensorflow-decision-forests>=1.0.1->tensorflowjs) (2022.7.1)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from chex>=0.1.5->optax->flax>=0.6.2->tensorflowjs) (0.12.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.8/dist-packages (from chex>=0.1.5->optax->flax>=0.6.2->tensorflowjs) (0.1.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (6.0.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (2022.12.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (3.2.2)
# Building wheels for collected packages: jax
#   Building wheel for jax (setup.py) ... done
#   Created wheel for jax: filename=jax-0.4.3-py3-none-any.whl size=1384905 sha256=20191f68d611d242af848e84a9e605c2113b73072c0d57064bbb46caff0919b4
#   Stored in directory: /root/.cache/pip/wheels/46/38/24/69c60b74118b6de655c576685cbe9c654f868ac27597ee5c98
# Successfully built jax
# Installing collected packages: cached_property, wurlitzer, tensorstore, pygments, packaging, mdurl, markdown-it-py, jax, rich, chex, optax, tensorflow-decision-forests, orbax, flax, tensorflowjs
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: jax
#     Found existing installation: jax 0.3.25
#     Uninstalling jax-0.3.25:
#       Successfully uninstalled jax-0.3.25
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# Successfully installed cached_property-1.5.2 chex-0.1.6 flax-0.6.5 jax-0.4.3 markdown-it-py-2.1.0 mdurl-0.1.2 optax-0.1.4 orbax-0.1.1 packaging-20.9 pygments-2.14.0 rich-13.3.1 tensorflow-decision-forests-1.2.0 tensorflowjs-4.2.0 tensorstore-0.1.31 wurlitzer-3.0.3

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport

# %%
# !{command}
# Out:
# 2023-02-10 00:25:00.286565: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-10 00:25:00.286775: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-10 00:25:00.286805: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-10 00:25:05.804396: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Writing weight file Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport/model.json...

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet --output_directory=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport

# %%
# !pip install jaxlib==0.4.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jaxlib==0.4.2 in /usr/local/lib/python3.8/dist-packages (0.4.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.8/dist-packages (from jaxlib==0.4.2) (1.7.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from jaxlib==0.4.2) (1.21.6)
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 167, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/req_command.py", line 199, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/commands/install.py", line 397, in run
#     conflicts = self._determine_conflicts(to_install)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/commands/install.py", line 529, in _determine_conflicts
#     return check_install_conflicts(to_install)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/operations/check.py", line 42, in create_package_set_from_installed
#     dependencies = list(dist.iter_dependencies())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/metadata/pkg_resources.py", line 202, in iter_dependencies
#     return self._dist.requires(extras)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2736, in requires
#     dm = self._dep_map
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3023, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3033, in _compute_dependencies
#     reqs.extend(parse_requirements(req))
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3094, in parse_requirements
#     yield Requirement(line)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3101, in __init__
#     super(Requirement, self).__init__(requirement_string)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/packaging/requirements.py", line 123, in __init__
#     self.marker: TOptional[Marker] = req.marker if req.marker else None
#   File "/usr/local/lib/python3.8/dist-packages/pip/_vendor/pyparsing/results.py", line 419, in __getattr__
#     try:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 221, in _main
#     return run(options, args)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/cli/base_command.py", line 205, in exc_logging_wrapper
#     logger.debug("Exception information:", exc_info=True)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1434, in debug
#     self._log(DEBUG, msg, args, **kwargs)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1589, in _log
#     self.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 954, in handle
#     self.emit(record)
#   File "/usr/lib/python3.8/logging/handlers.py", line 71, in emit
#     logging.FileHandler.emit(self, record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1187, in emit
#     StreamHandler.emit(self, record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/local/lib/python3.8/dist-packages/pip/_internal/utils/logging.py", line 110, in format
#     formatted = super().format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 676, in format
#     record.exc_text = self.formatException(record.exc_info)
#   File "/usr/lib/python3.8/logging/__init__.py", line 626, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "/usr/lib/python3.8/traceback.py", line 103, in print_exception
#     for line in TracebackException(
#   File "/usr/lib/python3.8/traceback.py", line 468, in __init__
#     def __init__(self, exc_type, exc_value, exc_traceback, *, limit=None,
# KeyboardInterrupt
# ^C

# %%
# !{command}
# Out:
# 2023-02-10 00:16:10.508526: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-10 00:16:10.508739: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-10 00:16:10.508772: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-10 00:16:17.670613: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0210 00:16:40.979652 140186599450432 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f7f485e61c0>, because it is not built.
# W0210 00:16:48.419738 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f7f485e61c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f7f482c1a60>, because it is not built.
# W0210 00:16:48.801080 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f7f482c1a60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f4807de80>, because it is not built.
# W0210 00:16:48.801388 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f4807de80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4807dbb0>, because it is not built.
# W0210 00:16:48.801543 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4807dbb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f7f482766d0>, because it is not built.
# W0210 00:16:48.801651 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f7f482766d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48249220>, because it is not built.
# W0210 00:16:48.801750 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48249220>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48249d60>, because it is not built.
# W0210 00:16:48.801848 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48249d60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f7f48076550>, because it is not built.
# W0210 00:16:48.801942 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f7f48076550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f482c5df0>, because it is not built.
# W0210 00:16:48.802032 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f482c5df0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4833af40>, because it is not built.
# W0210 00:16:48.802115 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4833af40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f7f48247550>, because it is not built.
# W0210 00:16:48.802197 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f7f48247550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48247f10>, because it is not built.
# W0210 00:16:48.802280 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48247f10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4838c370>, because it is not built.
# W0210 00:16:48.802362 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4838c370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f4826a580>, because it is not built.
# W0210 00:16:48.802461 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f4826a580>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48440e50>, because it is not built.
# W0210 00:16:48.802550 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48440e50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f483f8790>, because it is not built.
# W0210 00:16:48.802634 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f483f8790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f483f8e20>, because it is not built.
# W0210 00:16:48.802716 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f483f8e20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48415dc0>, because it is not built.
# W0210 00:16:48.802798 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48415dc0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f484152b0>, because it is not built.
# W0210 00:16:48.802881 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f484152b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f484154c0>, because it is not built.
# W0210 00:16:48.802962 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f484154c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4806f5b0>, because it is not built.
# W0210 00:16:48.803062 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4806f5b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48243190>, because it is not built.
# W0210 00:16:48.803152 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48243190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f33b8a520>, because it is not built.
# W0210 00:16:48.803236 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f33b8a520>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f33b8a7f0>, because it is not built.
# W0210 00:16:48.803319 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f33b8a7f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f33b8a820>, because it is not built.
# W0210 00:16:48.803407 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f33b8a820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f33f75ca0>, because it is not built.
# W0210 00:16:48.803511 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f33f75ca0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f33e050d0>, because it is not built.
# W0210 00:16:48.803601 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f33e050d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48289ca0>, because it is not built.
# W0210 00:16:48.803697 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48289ca0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48349550>, because it is not built.
# W0210 00:16:48.803791 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48349550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f33c5fca0>, because it is not built.
# W0210 00:16:48.803880 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f33c5fca0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4831c610>, because it is not built.
# W0210 00:16:48.803970 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4831c610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f4825c400>, because it is not built.
# W0210 00:16:48.804062 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f4825c400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4825c0d0>, because it is not built.
# W0210 00:16:48.804255 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4825c0d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48307fd0>, because it is not built.
# W0210 00:16:48.804353 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48307fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48307490>, because it is not built.
# W0210 00:16:48.804464 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48307490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f483ab460>, because it is not built.
# W0210 00:16:48.804556 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f483ab460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f483ab7c0>, because it is not built.
# W0210 00:16:48.804646 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f483ab7c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f483da9a0>, because it is not built.
# W0210 00:16:48.804737 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f483da9a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4830d370>, because it is not built.
# W0210 00:16:48.804830 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4830d370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f4830d460>, because it is not built.
# W0210 00:16:48.804914 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f4830d460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4830d580>, because it is not built.
# W0210 00:16:48.804998 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f4830d580>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48464460>, because it is not built.
# W0210 00:16:48.805095 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48464460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48464820>, because it is not built.
# W0210 00:16:48.805186 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48464820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48240fd0>, because it is not built.
# W0210 00:16:48.811419 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f7f48240fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48240a30>, because it is not built.
# W0210 00:16:48.811779 140186599450432 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f7f48240a30>, because it is not built.
# W0210 00:17:18.848515 140186599450432 save.py:271] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/assets
# I0210 00:17:26.796921 140186599450432 builder_impl.py:797] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/assets

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model --output_file=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}
# Out:
# 2021-04-03 11:55:38.653963: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# 2021-04-03 11:55:41.159460: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-03 11:55:41.160164: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library nvcuda.dll
# 2021-04-03 11:55:41.183623: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:2b:00.0 name: GeForce RTX 2070 SUPER computeCapability: 7.5
# coreClock: 1.785GHz coreCount: 40 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 417.29GiB/s
# 2021-04-03 11:55:41.183649: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# 2021-04-03 11:55:41.187402: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cublas64_11.dll
# 2021-04-03 11:55:41.187424: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cublasLt64_11.dll
# 2021-04-03 11:55:41.189452: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cufft64_10.dll
# 2021-04-03 11:55:41.190052: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library curand64_10.dll
# 2021-04-03 11:55:41.193535: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cusolver64_10.dll
# 2021-04-03 11:55:41.194888: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cusparse64_11.dll
# 2021-04-03 11:55:41.195377: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudnn64_8.dll
# 2021-04-03 11:55:41.195440: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-04-03 11:55:41.195644: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-04-03 11:55:41.196333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:2b:00.0 name: GeForce RTX 2070 SUPER computeCapability: 7.5
# coreClock: 1.785GHz coreCount: 40 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 417.29GiB/s
# 2021-04-03 11:55:41.196347: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# 2021-04-03 11:55:41.196353: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cublas64_11.dll
# 2021-04-03 11:55:41.196361: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cublasLt64_11.dll
# 2021-04-03 11:55:41.196366: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cufft64_10.dll
# 2021-04-03 11:55:41.196373: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library curand64_10.dll
# 2021-04-03 11:55:41.196378: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cusolver64_10.dll
# 2021-04-03 11:55:41.196385: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cusparse64_11.dll
# 2021-04-03 11:55:41.196389: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudnn64_8.dll
# 2021-04-03 11:55:41.196414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-04-03 11:55:41.624429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-03 11:55:41.624448: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-04-03 11:55:41.624452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-04-03 11:55:41.624581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6611 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2070 SUPER, pci bus id: 0000:2b:00.0, compute capability: 7.5)
# 2021-04-03 11:55:41.624988: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-03 11:55:50.392224: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:316] Ignored output_format.
# 2021-04-03 11:55:50.392245: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:319] Ignored drop_control_dependency.
# 2021-04-03 11:55:50.392250: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:325] Ignored change_concat_input_ranges.
# 2021-04-03 11:55:50.392901: I tensorflow/cc/saved_model/reader.cc:32] Reading SavedModel from: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model
# 2021-04-03 11:55:50.467288: I tensorflow/cc/saved_model/reader.cc:55] Reading meta graph with tags { serve }
# 2021-04-03 11:55:50.467341: I tensorflow/cc/saved_model/reader.cc:93] Reading SavedModel debug info (if present) from: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model
# 2021-04-03 11:55:50.467439: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-03 11:55:50.467446: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]
# 2021-04-03 11:55:50.467452: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-03 11:55:50.748887: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# 2021-04-03 11:55:50.790035: I tensorflow/cc/saved_model/loader.cc:206] Restoring SavedModel bundle.
# 2021-04-03 11:55:51.366069: I tensorflow/cc/saved_model/loader.cc:190] Running initialization op on SavedModel bundle at path: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model
# 2021-04-03 11:55:51.623706: I tensorflow/cc/saved_model/loader.cc:277] SavedModel load for tags { serve }; Status: success: OK. Took 1230797 microseconds.
# 2021-04-03 11:55:52.694959: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:194] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2021-04-03 11:55:53.295613: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:2b:00.0 name: GeForce RTX 2070 SUPER computeCapability: 7.5
# coreClock: 1.785GHz coreCount: 40 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 417.29GiB/s
# 2021-04-03 11:55:53.295643: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# 2021-04-03 11:55:53.295652: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cublas64_11.dll
# 2021-04-03 11:55:53.295658: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cublasLt64_11.dll
# 2021-04-03 11:55:53.295666: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cufft64_10.dll
# 2021-04-03 11:55:53.295671: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library curand64_10.dll
# 2021-04-03 11:55:53.295678: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cusolver64_10.dll
# 2021-04-03 11:55:53.295683: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cusparse64_11.dll
# 2021-04-03 11:55:53.295689: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudnn64_8.dll
# 2021-04-03 11:55:53.295714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-04-03 11:55:53.295753: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-03 11:55:53.295759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-04-03 11:55:53.295762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-04-03 11:55:53.295817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6611 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2070 SUPER, pci bus id: 0000:2b:00.0, compute capability: 7.5)
# 2021-04-03 11:55:53.295834: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !zip -r '/content/Tensorflow.zip' '/content/Tensorflow'
# Out:
#   adding: content/Tensorflow/ (stored 0%)
#   adding: content/Tensorflow/models/ (stored 0%)
#   adding: content/Tensorflow/models/orbit/ (stored 0%)
#   adding: content/Tensorflow/models/orbit/standard_runner_test.py (deflated 72%)
#   adding: content/Tensorflow/models/orbit/utils/ (stored 0%)
#   adding: content/Tensorflow/models/orbit/utils/common.py (deflated 58%)
#   adding: content/Tensorflow/models/orbit/utils/summary_manager.py (deflated 63%)
#   adding: content/Tensorflow/models/orbit/utils/__init__.py (deflated 52%)
#   adding: content/Tensorflow/models/orbit/utils/summary_manager_interface.py (deflated 56%)
#   adding: content/Tensorflow/models/orbit/utils/loop_fns.py (deflated 70%)
#   adding: content/Tensorflow/models/orbit/utils/epoch_helper.py (deflated 59%)
#   adding: content/Tensorflow/models/orbit/utils/common_test.py (deflated 44%)
#   adding: content/Tensorflow/models/orbit/utils/tpu_summaries.py (deflated 63%)
#   adding: content/Tensorflow/models/orbit/utils/tpu_summaries_test.py (deflated 70%)
#   adding: content/Tensorflow/models/orbit/__init__.py (deflated 54%)
#   adding: content/Tensorflow/models/orbit/controller.py (deflated 71%)
#   adding: content/Tensorflow/models/orbit/LICENSE (deflated 65%)
#   adding: content/Tensorflow/models/orbit/controller_test.py (deflated 86%)
#   adding: content/Tensorflow/models/orbit/runner.py (deflated 60%)
#   adding: content/Tensorflow/models/orbit/standard_runner.py (deflated 74%)
#   adding: content/Tensorflow/models/orbit/README.md (deflated 40%)
#   adding: content/Tensorflow/models/orbit/actions/ (stored 0%)
#   adding: content/Tensorflow/models/orbit/actions/new_best_metric.py (deflated 66%)
#   adding: content/Tensorflow/models/orbit/actions/conditional_action_test.py (deflated 48%)
#   adding: content/Tensorflow/models/orbit/actions/__init__.py (deflated 55%)
#   adding: content/Tensorflow/models/orbit/actions/export_saved_model_test.py (deflated 79%)
#   adding: content/Tensorflow/models/orbit/actions/new_best_metric_test.py (deflated 72%)
#   adding: content/Tensorflow/models/orbit/actions/conditional_action.py (deflated 52%)
#   adding: content/Tensorflow/models/orbit/actions/export_saved_model.py (deflated 61%)
#   adding: content/Tensorflow/models/orbit/actions/save_checkpoint_if_preempted.py (deflated 59%)
#   adding: content/Tensorflow/models/orbit/examples/ (stored 0%)
#   adding: content/Tensorflow/models/orbit/examples/__init__.py (deflated 37%)
#   adding: content/Tensorflow/models/orbit/examples/single_task/ (stored 0%)
#   adding: content/Tensorflow/models/orbit/examples/single_task/single_task_trainer.py (deflated 61%)
#   adding: content/Tensorflow/models/orbit/examples/single_task/__init__.py (deflated 37%)
#   adding: content/Tensorflow/models/orbit/examples/single_task/single_task_evaluator_test.py (deflated 55%)
#   adding: content/Tensorflow/models/orbit/examples/single_task/single_task_evaluator.py (deflated 57%)
#   adding: content/Tensorflow/models/orbit/examples/single_task/single_task_trainer_test.py (deflated 52%)
#   adding: content/Tensorflow/models/tensorflow_models/ (stored 0%)
#   adding: content/Tensorflow/models/tensorflow_models/__init__.py (deflated 45%)
#   adding: content/Tensorflow/models/tensorflow_models/vision/ (stored 0%)
#   adding: content/Tensorflow/models/tensorflow_models/vision/__init__.py (deflated 45%)
#   adding: content/Tensorflow/models/tensorflow_models/nlp/ (stored 0%)
#   adding: content/Tensorflow/models/tensorflow_models/nlp/__init__.py (deflated 43%)
#   adding: content/Tensorflow/models/tensorflow_models/tensorflow_models_test.py (deflated 46%)
#   adding: content/Tensorflow/models/tensorflow_models/tensorflow_models_pypi.ipynb (deflated 76%)
#   adding: content/Tensorflow/models/research/ (stored 0%)
#   adding: content/Tensorflow/models/research/audioset/ (stored 0%)
#   adding: content/Tensorflow/models/research/audioset/vggish/ (stored 0%)
#   adding: content/Tensorflow/models/research/audioset/vggish/vggish_smoke_test.py (deflated 56%)
#   adding: content/Tensorflow/models/research/audioset/vggish/vggish_export_tfhub.py (deflated 60%)
#   adding: content/Tensorflow/models/research/audioset/vggish/vggish_train_demo.py (deflated 60%)
#   adding: content/Tensorflow/models/research/audioset/vggish/vggish_input.py (deflated 58%)
#   adding: content/Tensorflow/models/research/audioset/vggish/vggish_inference_demo.py (deflated 62%)
#   adding: content/Tensorflow/models/research/audioset/vggish/vggish_postprocess.py (deflated 60%)
#   adding: content/Tensorflow/models/research/audioset/vggish/vggish_params.py (deflated 49%)
#   adding: content/Tensorflow/models/research/audioset/vggish/README.md (deflated 59%)
#   adding: content/Tensorflow/models/research/audioset/vggish/vggish_slim.py (deflated 60%)
#   adding: content/Tensorflow/models/research/audioset/vggish/mel_features.py (deflated 64%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/ (stored 0%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/yamnet_class_map.csv (deflated 51%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/yamnet_visualization.ipynb (deflated 28%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/inference.py (deflated 51%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/export.py (deflated 69%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/yamnet_test.py (deflated 59%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/README.md (deflated 53%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/params.py (deflated 50%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/features.py (deflated 67%)
#   adding: content/Tensorflow/models/research/audioset/yamnet/yamnet.py (deflated 69%)
#   adding: content/Tensorflow/models/research/audioset/README.md (deflated 55%)
#   adding: content/Tensorflow/models/research/nst_blogpost/ (stored 0%)
#   adding: content/Tensorflow/models/research/nst_blogpost/Green_Sea_Turtle_grazing_seagrass.jpg (deflated 1%)
#   adding: content/Tensorflow/models/research/nst_blogpost/4_Neural_Style_Transfer_with_Eager_Execution.ipynb (deflated 76%)
#   adding: content/Tensorflow/models/research/nst_blogpost/wave_turtle.png (deflated 0%)
#   adding: content/Tensorflow/models/research/nst_blogpost/The_Great_Wave_off_Kanagawa.jpg (deflated 0%)
#   adding: content/Tensorflow/models/research/delf/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/download_dataset.sh (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/__init__.py (deflated 47%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/global_features/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/global_features/__init__.py (deflated 45%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/global_features/train_utils.py (deflated 71%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/global_features/train.py (deflated 69%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/global_features/README.md (deflated 56%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/global_features_utils.py (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/matched_images_demo.png (deflated 1%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/train.py (deflated 73%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/README.md (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/losses/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/losses/__init__.py (deflated 44%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/losses/ranking_losses.py (deflated 72%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/losses/ranking_losses_test.py (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/build_image_dataset.py (deflated 72%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/install_delf.sh (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/delg_model.py (deflated 69%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/export_local_and_global_model.py (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/delf_model.py (deflated 69%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/__init__.py (deflated 53%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/global_model.py (deflated 66%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/resnet50.py (deflated 76%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/delg_model_test.py (deflated 70%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/export_CNN_global.py (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/export_local_model.py (deflated 62%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/export_model_utils.py (deflated 77%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/delf_model_test.py (deflated 64%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/export_global_model.py (deflated 69%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/model/global_model_test.py (deflated 61%)
#   adding: content/Tensorflow/models/research/delf/delf/python/training/tensorboard_utils.py (deflated 47%)
#   adding: content/Tensorflow/models/research/delf/delf/python/delg/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/delg/r50delg_gldv2clean_config.pbtxt (deflated 54%)
#   adding: content/Tensorflow/models/research/delf/delf/python/delg/r101delg_gld_config.pbtxt (deflated 54%)
#   adding: content/Tensorflow/models/research/delf/delf/python/delg/r101delg_gldv2clean_config.pbtxt (deflated 54%)
#   adding: content/Tensorflow/models/research/delf/delf/python/delg/extract_features.py (deflated 64%)
#   adding: content/Tensorflow/models/research/delf/delf/python/delg/measure_latency.py (deflated 58%)
#   adding: content/Tensorflow/models/research/delf/delf/python/delg/r50delg_gld_config.pbtxt (deflated 55%)
#   adding: content/Tensorflow/models/research/delf/delf/python/delg/perform_retrieval.py (deflated 70%)
#   adding: content/Tensorflow/models/research/delf/delf/python/delg/DELG_INSTRUCTIONS.md (deflated 68%)
#   adding: content/Tensorflow/models/research/delf/delf/python/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/normalization_layers/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/normalization_layers/__init__.py (deflated 44%)
#   adding: content/Tensorflow/models/research/delf/delf/python/normalization_layers/normalization_test.py (deflated 46%)
#   adding: content/Tensorflow/models/research/delf/delf/python/normalization_layers/normalization.py (deflated 49%)
#   adding: content/Tensorflow/models/research/delf/delf/python/pooling_layers/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/pooling_layers/__init__.py (deflated 44%)
#   adding: content/Tensorflow/models/research/delf/delf/python/pooling_layers/pooling.py (deflated 69%)
#   adding: content/Tensorflow/models/research/delf/delf/python/pooling_layers/pooling_test.py (deflated 66%)
#   adding: content/Tensorflow/models/research/delf/delf/python/whiten_test.py (deflated 63%)
#   adding: content/Tensorflow/models/research/delf/delf/python/feature_io_test.py (deflated 71%)
#   adding: content/Tensorflow/models/research/delf/delf/python/utils.py (deflated 60%)
#   adding: content/Tensorflow/models/research/delf/delf/python/feature_aggregation_extractor_test.py (deflated 89%)
#   adding: content/Tensorflow/models/research/delf/delf/python/feature_aggregation_extractor.py (deflated 77%)
#   adding: content/Tensorflow/models/research/delf/delf/python/feature_aggregation_similarity.py (deflated 74%)
#   adding: content/Tensorflow/models/research/delf/delf/python/utils_test.py (deflated 75%)
#   adding: content/Tensorflow/models/research/delf/delf/python/feature_io.py (deflated 77%)
#   adding: content/Tensorflow/models/research/delf/delf/python/feature_extractor.py (deflated 68%)
#   adding: content/Tensorflow/models/research/delf/delf/python/box_io_test.py (deflated 62%)
#   adding: content/Tensorflow/models/research/delf/delf/python/feature_aggregation_similarity_test.py (deflated 77%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/DETECT_TO_RETRIEVE_INSTRUCTIONS.md (deflated 73%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/__init__.py (deflated 49%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/delf_gld_config.pbtxt (deflated 53%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/index_aggregation_config.pbtxt (deflated 34%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/extract_index_boxes_and_features.py (deflated 64%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/aggregation_extraction.py (deflated 68%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/boxes_and_features_extraction.py (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/cluster_delf_features.py (deflated 63%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/extract_aggregation.py (deflated 61%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/extract_query_features.py (deflated 61%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/query_aggregation_config.pbtxt (deflated 32%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/perform_retrieval.py (deflated 72%)
#   adding: content/Tensorflow/models/research/delf/delf/python/detect_to_retrieve/image_reranking.py (deflated 71%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/delf_config_example.pbtxt (deflated 53%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/match_images.py (deflated 62%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/matched_images_example.jpg (deflated 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/extract_features.py (deflated 60%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/detector.py (deflated 52%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/extract_boxes.py (deflated 64%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/detection_example_2.jpg (deflated 2%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/detection_example_1.jpg (deflated 3%)
#   adding: content/Tensorflow/models/research/delf/delf/python/examples/extractor.py (deflated 75%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datum_io_test.py (deflated 68%)
#   adding: content/Tensorflow/models/research/delf/delf/python/box_io.py (deflated 72%)
#   adding: content/Tensorflow/models/research/delf/delf/python/feature_extractor_test.py (deflated 59%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datum_io.py (deflated 73%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/utils.py (deflated 59%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/tuples_dataset_test.py (deflated 54%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/utils_test.py (deflated 59%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/sfm120k/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/sfm120k/dataset_download.py (deflated 70%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/sfm120k/__init__.py (deflated 47%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/sfm120k/sfm120k.py (deflated 64%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/sfm120k/sfm120k_test.py (deflated 48%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/generic_dataset_test.py (deflated 52%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/generic_dataset.py (deflated 56%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/revisited_op/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/revisited_op/dataset_test.py (deflated 78%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/revisited_op/__init__.py (deflated 47%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/revisited_op/dataset.py (deflated 73%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/__init__.py (deflated 48%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/metrics_test.py (deflated 79%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/googlelandmarks.py (deflated 65%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/compute_recognition_metrics.py (deflated 66%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/compute_retrieval_metrics.py (deflated 68%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/metrics.py (deflated 75%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/dataset_file_io_test.py (deflated 77%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/dataset_file_io.py (deflated 69%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/README.md (deflated 64%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/google_landmarks_dataset/rn101_af_gldv2clean_config.pbtxt (deflated 35%)
#   adding: content/Tensorflow/models/research/delf/delf/python/datasets/tuples_dataset.py (deflated 68%)
#   adding: content/Tensorflow/models/research/delf/delf/python/whiten.py (deflated 62%)
#   adding: content/Tensorflow/models/research/delf/delf/__init__.py (deflated 62%)
#   adding: content/Tensorflow/models/research/delf/delf/protos/ (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/protos/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/delf/delf/protos/aggregation_config.proto (deflated 59%)
#   adding: content/Tensorflow/models/research/delf/delf/protos/datum.proto (deflated 59%)
#   adding: content/Tensorflow/models/research/delf/delf/protos/box.proto (deflated 44%)
#   adding: content/Tensorflow/models/research/delf/delf/protos/delf_config.proto (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/delf/protos/feature.proto (deflated 48%)
#   adding: content/Tensorflow/models/research/delf/EXTRACTION_MATCHING.md (deflated 58%)
#   adding: content/Tensorflow/models/research/delf/setup.py (deflated 47%)
#   adding: content/Tensorflow/models/research/delf/INSTALL_INSTRUCTIONS.md (deflated 64%)
#   adding: content/Tensorflow/models/research/delf/.gitignore (deflated 20%)
#   adding: content/Tensorflow/models/research/delf/README.md (deflated 67%)
#   adding: content/Tensorflow/models/research/delf/DETECTION.md (deflated 53%)
#   adding: content/Tensorflow/models/research/rebar/ (stored 0%)
#   adding: content/Tensorflow/models/research/rebar/config.py (deflated 45%)
#   adding: content/Tensorflow/models/research/rebar/download_data.py (deflated 60%)
#   adding: content/Tensorflow/models/research/rebar/utils.py (deflated 57%)
#   adding: content/Tensorflow/models/research/rebar/logger.py (deflated 47%)
#   adding: content/Tensorflow/models/research/rebar/README.md (deflated 57%)
#   adding: content/Tensorflow/models/research/rebar/rebar_train.py (deflated 65%)
#   adding: content/Tensorflow/models/research/rebar/rebar.py (deflated 81%)
#   adding: content/Tensorflow/models/research/rebar/datasets.py (deflated 60%)
#   adding: content/Tensorflow/models/research/slim/ (stored 0%)
#   adding: content/Tensorflow/models/research/slim/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/slim/export_inference_graph.py (deflated 63%)
#   adding: content/Tensorflow/models/research/slim/deployment/ (stored 0%)
#   adding: content/Tensorflow/models/research/slim/deployment/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/slim/deployment/model_deploy_test.py (deflated 88%)
#   adding: content/Tensorflow/models/research/slim/deployment/model_deploy.py (deflated 74%)
#   adding: content/Tensorflow/models/research/slim/WORKSPACE (stored 0%)
#   adding: content/Tensorflow/models/research/slim/train_image_classifier.py (deflated 73%)
#   adding: content/Tensorflow/models/research/slim/preprocessing/ (stored 0%)
#   adding: content/Tensorflow/models/research/slim/preprocessing/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/slim/preprocessing/preprocessing_factory.py (deflated 70%)
#   adding: content/Tensorflow/models/research/slim/preprocessing/cifarnet_preprocessing.py (deflated 73%)
#   adding: content/Tensorflow/models/research/slim/preprocessing/inception_preprocessing.py (deflated 74%)
#   adding: content/Tensorflow/models/research/slim/preprocessing/lenet_preprocessing.py (deflated 55%)
#   adding: content/Tensorflow/models/research/slim/preprocessing/vgg_preprocessing.py (deflated 73%)
#   adding: content/Tensorflow/models/research/slim/setup.py (deflated 47%)
#   adding: content/Tensorflow/models/research/slim/export_inference_graph_test.py (deflated 49%)
#   adding: content/Tensorflow/models/research/slim/scripts/ (stored 0%)
#   adding: content/Tensorflow/models/research/slim/scripts/train_cifarnet_on_cifar10.sh (deflated 55%)
#   adding: content/Tensorflow/models/research/slim/scripts/train_lenet_on_mnist.sh (deflated 54%)
#   adding: content/Tensorflow/models/research/slim/scripts/finetune_inception_resnet_v2_on_flowers.sh (deflated 68%)
#   adding: content/Tensorflow/models/research/slim/scripts/finetune_inception_v3_on_flowers.sh (deflated 67%)
#   adding: content/Tensorflow/models/research/slim/scripts/finetune_inception_v1_on_flowers.sh (deflated 67%)
#   adding: content/Tensorflow/models/research/slim/scripts/export_mobilenet.sh (deflated 63%)
#   adding: content/Tensorflow/models/research/slim/scripts/finetune_resnet_v1_50_on_flowers.sh (deflated 67%)
#   adding: content/Tensorflow/models/research/slim/BUILD (deflated 91%)
#   adding: content/Tensorflow/models/research/slim/README.md (deflated 70%)
#   adding: content/Tensorflow/models/research/slim/download_and_convert_data.py (deflated 64%)
#   adding: content/Tensorflow/models/research/slim/slim_walkthrough.ipynb (deflated 78%)
#   adding: content/Tensorflow/models/research/slim/eval_image_classifier.py (deflated 66%)
#   adding: content/Tensorflow/models/research/slim/datasets/ (stored 0%)
#   adding: content/Tensorflow/models/research/slim/datasets/imagenet.py (deflated 61%)
#   adding: content/Tensorflow/models/research/slim/datasets/build_imagenet_data.py (deflated 73%)
#   adding: content/Tensorflow/models/research/slim/datasets/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/slim/datasets/imagenet_2012_validation_synset_labels.txt (deflated 76%)
#   adding: content/Tensorflow/models/research/slim/datasets/flowers.py (deflated 56%)
#   adding: content/Tensorflow/models/research/slim/datasets/download_and_convert_mnist.py (deflated 67%)
#   adding: content/Tensorflow/models/research/slim/datasets/visualwakewords.py (deflated 60%)
#   adding: content/Tensorflow/models/research/slim/datasets/cifar10.py (deflated 56%)
#   adding: content/Tensorflow/models/research/slim/datasets/dataset_factory.py (deflated 54%)
#   adding: content/Tensorflow/models/research/slim/datasets/imagenet_metadata.txt (deflated 60%)
#   adding: content/Tensorflow/models/research/slim/datasets/imagenet_lsvrc_2015_synsets.txt (deflated 62%)
#   adding: content/Tensorflow/models/research/slim/datasets/download_and_convert_flowers.py (deflated 64%)
#   adding: content/Tensorflow/models/research/slim/datasets/download_and_convert_visualwakewords.py (deflated 67%)
#   adding: content/Tensorflow/models/research/slim/datasets/process_bounding_boxes.py (deflated 63%)
#   adding: content/Tensorflow/models/research/slim/datasets/download_and_convert_visualwakewords_lib.py (deflated 72%)
#   adding: content/Tensorflow/models/research/slim/datasets/download_and_convert_imagenet.sh (deflated 60%)
#   adding: content/Tensorflow/models/research/slim/datasets/download_imagenet.sh (deflated 59%)
#   adding: content/Tensorflow/models/research/slim/datasets/download_and_convert_cifar10.py (deflated 63%)
#   adding: content/Tensorflow/models/research/slim/datasets/mnist.py (deflated 56%)
#   adding: content/Tensorflow/models/research/slim/datasets/dataset_utils.py (deflated 68%)
#   adding: content/Tensorflow/models/research/slim/datasets/preprocess_imagenet_validation_data.py (deflated 56%)
#   adding: content/Tensorflow/models/research/slim/nets/ (stored 0%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_v1.py (deflated 83%)
#   adding: content/Tensorflow/models/research/slim/nets/nets_factory_test.py (deflated 72%)
#   adding: content/Tensorflow/models/research/slim/nets/i3d.py (deflated 62%)
#   adding: content/Tensorflow/models/research/slim/nets/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/slim/nets/overfeat_test.py (deflated 80%)
#   adding: content/Tensorflow/models/research/slim/nets/resnet_utils.py (deflated 65%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_v2_test.py (deflated 82%)
#   adding: content/Tensorflow/models/research/slim/nets/lenet.py (deflated 58%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/ (stored 0%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/mobilenet_example.ipynb (deflated 28%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/mobilenet_v2_test.py (deflated 72%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/mobilenet_v2.py (deflated 68%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/g3doc/ (stored 0%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/g3doc/madds_top1_accuracy.png (deflated 2%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/g3doc/edgetpu_latency.png (deflated 8%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/g3doc/latency_pixel1.png (deflated 1%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/mobilenet_v3_test.py (deflated 76%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/mobilenet_v3.py (deflated 88%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/mnet_v1_vs_v2_pixel1_latency.png (deflated 10%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/README.md (deflated 76%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/conv_blocks.py (deflated 71%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet/mobilenet.py (deflated 66%)
#   adding: content/Tensorflow/models/research/slim/nets/overfeat.py (deflated 65%)
#   adding: content/Tensorflow/models/research/slim/nets/dcgan_test.py (deflated 67%)
#   adding: content/Tensorflow/models/research/slim/nets/pix2pix_test.py (deflated 76%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_v2.py (deflated 83%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet_v1.png (deflated 2%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet_v1_eval.py (deflated 62%)
#   adding: content/Tensorflow/models/research/slim/nets/resnet_v2_test.py (deflated 81%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet_v1_test.py (deflated 88%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet_v1.py (deflated 74%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_v3_test.py (deflated 82%)
#   adding: content/Tensorflow/models/research/slim/nets/resnet_v1_test.py (deflated 83%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_v4.py (deflated 81%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_resnet_v2.py (deflated 77%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_v3.py (deflated 84%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_v4_test.py (deflated 82%)
#   adding: content/Tensorflow/models/research/slim/nets/i3d_test.py (deflated 74%)
#   adding: content/Tensorflow/models/research/slim/nets/inception.py (deflated 65%)
#   adding: content/Tensorflow/models/research/slim/nets/dcgan.py (deflated 70%)
#   adding: content/Tensorflow/models/research/slim/nets/resnet_v2.py (deflated 73%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_utils.py (deflated 59%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet_v1.md (deflated 74%)
#   adding: content/Tensorflow/models/research/slim/nets/vgg.py (deflated 82%)
#   adding: content/Tensorflow/models/research/slim/nets/i3d_utils.py (deflated 72%)
#   adding: content/Tensorflow/models/research/slim/nets/cyclegan.py (deflated 68%)
#   adding: content/Tensorflow/models/research/slim/nets/nets_factory.py (deflated 72%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_v1_test.py (deflated 80%)
#   adding: content/Tensorflow/models/research/slim/nets/s3dg.py (deflated 80%)
#   adding: content/Tensorflow/models/research/slim/nets/s3dg_test.py (deflated 74%)
#   adding: content/Tensorflow/models/research/slim/nets/vgg_test.py (deflated 91%)
#   adding: content/Tensorflow/models/research/slim/nets/inception_resnet_v2_test.py (deflated 84%)
#   adding: content/Tensorflow/models/research/slim/nets/pix2pix.py (deflated 66%)
#   adding: content/Tensorflow/models/research/slim/nets/alexnet.py (deflated 63%)
#   adding: content/Tensorflow/models/research/slim/nets/cifarnet.py (deflated 61%)
#   adding: content/Tensorflow/models/research/slim/nets/cyclegan_test.py (deflated 71%)
#   adding: content/Tensorflow/models/research/slim/nets/resnet_v1.py (deflated 74%)
#   adding: content/Tensorflow/models/research/slim/nets/nasnet/ (stored 0%)
#   adding: content/Tensorflow/models/research/slim/nets/nasnet/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/slim/nets/nasnet/nasnet_utils_test.py (deflated 61%)
#   adding: content/Tensorflow/models/research/slim/nets/nasnet/nasnet_test.py (deflated 87%)
#   adding: content/Tensorflow/models/research/slim/nets/nasnet/nasnet_utils.py (deflated 74%)
#   adding: content/Tensorflow/models/research/slim/nets/nasnet/README.md (deflated 61%)
#   adding: content/Tensorflow/models/research/slim/nets/nasnet/pnasnet_test.py (deflated 83%)
#   adding: content/Tensorflow/models/research/slim/nets/nasnet/nasnet.py (deflated 81%)
#   adding: content/Tensorflow/models/research/slim/nets/nasnet/pnasnet.py (deflated 75%)
#   adding: content/Tensorflow/models/research/slim/nets/mobilenet_v1_train.py (deflated 65%)
#   adding: content/Tensorflow/models/research/slim/nets/post_training_quantization.py (deflated 63%)
#   adding: content/Tensorflow/models/research/slim/nets/alexnet_test.py (deflated 80%)
#   adding: content/Tensorflow/models/research/lfads/ (stored 0%)
#   adding: content/Tensorflow/models/research/lfads/plot_lfads.py (deflated 69%)
#   adding: content/Tensorflow/models/research/lfads/utils.py (deflated 71%)
#   adding: content/Tensorflow/models/research/lfads/distributions.py (deflated 73%)
#   adding: content/Tensorflow/models/research/lfads/run_lfads.py (deflated 69%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/ (stored 0%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/generate_itb_data.py (deflated 67%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/generate_chaotic_rnn_data.py (deflated 63%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/trained_itb/ (stored 0%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/trained_itb/model-65000.meta (deflated 93%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/trained_itb/model-65000.index (deflated 32%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/trained_itb/model-65000.data-00000-of-00001 (deflated 8%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/generate_labeled_rnn_data.py (deflated 65%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/run_generate_synth_data.sh (deflated 73%)
#   adding: content/Tensorflow/models/research/lfads/synth_data/synthetic_data_utils.py (deflated 63%)
#   adding: content/Tensorflow/models/research/lfads/lfads.py (deflated 78%)
#   adding: content/Tensorflow/models/research/lfads/README.md (deflated 66%)
#   adding: content/Tensorflow/models/research/attention_ocr/ (stored 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/ (stored 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/sequence_layers.py (deflated 72%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/metrics_test.py (deflated 66%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/utils.py (deflated 56%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/ (stored 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_28.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_20.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_02.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_31.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_08.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_15.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_19.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_01.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_09.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_22.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_06.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_14.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_11.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_12.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_13.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_10.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_27.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_30.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_07.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_21.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_26.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_29.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_17.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_18.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_04.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_16.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_24.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_23.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_00.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_05.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_03.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/testdata/fsns_train_25.png (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/common_flags.py (deflated 64%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/eval.py (deflated 56%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/model_test.py (deflated 75%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/inception_preprocessing.py (deflated 72%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/sequence_layers_test.py (deflated 71%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/metrics.py (deflated 69%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/demo_inference.py (deflated 60%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/data_provider.py (deflated 65%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/all_jobs.screenrc (deflated 55%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/train.py (deflated 66%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/model.py (deflated 71%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/data_provider_test.py (deflated 60%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/model_export_lib.py (deflated 61%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/model_export.py (deflated 63%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/demo_inference_test.py (deflated 74%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/model_export_test.py (deflated 64%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/ (stored 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/__init__.py (deflated 44%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/testdata/ (stored 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/testdata/fsns/ (stored 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/testdata/fsns/download_data.py (deflated 46%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/testdata/fsns/charset_size=134.txt (deflated 33%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/testdata/fsns/links.txt (deflated 15%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/testdata/fsns/fsns-00000-of-00001 (deflated 0%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/fsns_test.py (deflated 59%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/unittest_utils.py (deflated 52%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/unittest_utils_test.py (deflated 55%)
#   adding: content/Tensorflow/models/research/attention_ocr/python/datasets/fsns.py (deflated 63%)
#   adding: content/Tensorflow/models/research/attention_ocr/README.md (deflated 63%)
#   adding: content/Tensorflow/models/research/cognitive_planning/ (stored 0%)
#   adding: content/Tensorflow/models/research/cognitive_planning/string_int_label_map_pb2.py (deflated 73%)
#   adding: content/Tensorflow/models/research/cognitive_planning/visualization_utils.py (deflated 76%)
#   adding: content/Tensorflow/models/research/cognitive_planning/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/cognitive_planning/train_supervised_active_vision.sh (deflated 48%)
#   adding: content/Tensorflow/models/research/cognitive_planning/viz_active_vision_dataset_main.py (deflated 69%)
#   adding: content/Tensorflow/models/research/cognitive_planning/tasks.py (deflated 77%)
#   adding: content/Tensorflow/models/research/cognitive_planning/preprocessing/ (stored 0%)
#   adding: content/Tensorflow/models/research/cognitive_planning/preprocessing/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/cognitive_planning/preprocessing/preprocessing_factory.py (deflated 67%)
#   adding: content/Tensorflow/models/research/cognitive_planning/preprocessing/cifarnet_preprocessing.py (deflated 71%)
#   adding: content/Tensorflow/models/research/cognitive_planning/preprocessing/inception_preprocessing.py (deflated 73%)
#   adding: content/Tensorflow/models/research/cognitive_planning/preprocessing/lenet_preprocessing.py (deflated 52%)
#   adding: content/Tensorflow/models/research/cognitive_planning/preprocessing/vgg_preprocessing.py (deflated 73%)
#   adding: content/Tensorflow/models/research/cognitive_planning/embedders.py (deflated 74%)
#   adding: content/Tensorflow/models/research/cognitive_planning/policies.py (deflated 72%)
#   adding: content/Tensorflow/models/research/cognitive_planning/standard_fields.py (deflated 74%)
#   adding: content/Tensorflow/models/research/cognitive_planning/label_map.txt (deflated 78%)
#   adding: content/Tensorflow/models/research/cognitive_planning/label_map_util.py (deflated 66%)
#   adding: content/Tensorflow/models/research/cognitive_planning/BUILD (deflated 40%)
#   adding: content/Tensorflow/models/research/cognitive_planning/README.md (deflated 63%)
#   adding: content/Tensorflow/models/research/cognitive_planning/command (deflated 46%)
#   adding: content/Tensorflow/models/research/cognitive_planning/train_supervised_active_vision.py (deflated 69%)
#   adding: content/Tensorflow/models/research/cognitive_planning/envs/ (stored 0%)
#   adding: content/Tensorflow/models/research/cognitive_planning/envs/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/cognitive_planning/envs/configs/ (stored 0%)
#   adding: content/Tensorflow/models/research/cognitive_planning/envs/configs/active_vision_config.gin (deflated 64%)
#   adding: content/Tensorflow/models/research/cognitive_planning/envs/util.py (deflated 53%)
#   adding: content/Tensorflow/models/research/cognitive_planning/envs/active_vision_dataset_env.py (deflated 74%)
#   adding: content/Tensorflow/models/research/cognitive_planning/envs/task_env.py (deflated 66%)
#   adding: content/Tensorflow/models/research/setup.py (deflated 54%)
#   adding: content/Tensorflow/models/research/autoaugment/ (stored 0%)
#   adding: content/Tensorflow/models/research/autoaugment/train_cifar.py (deflated 70%)
#   adding: content/Tensorflow/models/research/autoaugment/shake_drop.py (deflated 68%)
#   adding: content/Tensorflow/models/research/autoaugment/helper_utils.py (deflated 65%)
#   adding: content/Tensorflow/models/research/autoaugment/data_utils.py (deflated 68%)
#   adding: content/Tensorflow/models/research/autoaugment/augmentation_transforms.py (deflated 71%)
#   adding: content/Tensorflow/models/research/autoaugment/policies.py (deflated 77%)
#   adding: content/Tensorflow/models/research/autoaugment/shake_shake.py (deflated 64%)
#   adding: content/Tensorflow/models/research/autoaugment/custom_ops.py (deflated 66%)
#   adding: content/Tensorflow/models/research/autoaugment/README.md (deflated 57%)
#   adding: content/Tensorflow/models/research/autoaugment/wrn.py (deflated 66%)
#   adding: content/Tensorflow/models/research/deep_speech/ (stored 0%)
#   adding: content/Tensorflow/models/research/deep_speech/deep_speech_model.py (deflated 65%)
#   adding: content/Tensorflow/models/research/deep_speech/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/deep_speech/deep_speech.py (deflated 67%)
#   adding: content/Tensorflow/models/research/deep_speech/requirements.txt (deflated 13%)
#   adding: content/Tensorflow/models/research/deep_speech/README.md (deflated 57%)
#   adding: content/Tensorflow/models/research/deep_speech/run_deep_speech.sh (deflated 63%)
#   adding: content/Tensorflow/models/research/deep_speech/data/ (stored 0%)
#   adding: content/Tensorflow/models/research/deep_speech/data/featurizer.py (deflated 58%)
#   adding: content/Tensorflow/models/research/deep_speech/data/vocabulary.txt (deflated 27%)
#   adding: content/Tensorflow/models/research/deep_speech/data/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/deep_speech/data/download.py (deflated 66%)
#   adding: content/Tensorflow/models/research/deep_speech/data/dataset.py (deflated 67%)
#   adding: content/Tensorflow/models/research/deep_speech/decoder.py (deflated 58%)
#   adding: content/Tensorflow/models/research/marco/ (stored 0%)
#   adding: content/Tensorflow/models/research/marco/Automated_Marco.py (deflated 55%)
#   adding: content/Tensorflow/models/research/marco/jpeg2json.py (deflated 41%)
#   adding: content/Tensorflow/models/research/marco/request.json (deflated 25%)
#   adding: content/Tensorflow/models/research/marco/README.md (deflated 55%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/ (stored 0%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/models/ (stored 0%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/models/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/models/mobilenet_defs.py (deflated 72%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/models/mobilenet_defs_test.py (deflated 79%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/models/lstm_ssd_mobilenet_v1_feature_extractor_test.py (deflated 70%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/models/lstm_ssd_interleaved_mobilenet_v2_feature_extractor.py (deflated 72%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/models/lstm_ssd_interleaved_mobilenet_v2_feature_extractor_test.py (deflated 80%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/models/lstm_ssd_mobilenet_v1_feature_extractor.py (deflated 69%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/utils/ (stored 0%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/utils/config_util.py (deflated 70%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/utils/__init__.py (stored 0%)
#   adding: content/Tensorflow/models/research/lstm_object_detection/utils/config_util_test.py (deflated 71%)
# ...
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/ckpt-3.data-00000-of-00001 (deflated 7%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/ckpt-1.index (deflated 81%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/assets/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/fingerprint.pb (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/variables/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/variables/variables.index (deflated 78%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/saved_model.pb (deflated 91%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/ckpt-2.index (deflated 82%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/ckpt-1.data-00000-of-00001 (deflated 8%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config (deflated 69%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/ckpt-3.index (deflated 82%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/.ipynb_checkpoints/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/checkpoint (deflated 63%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/ckpt-2.data-00000-of-00001 (deflated 7%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/fingerprint.pb (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/variables/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/variables/variables.index (deflated 78%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/saved_model.pb (deflated 92%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config (deflated 69%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/checkpoint/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/checkpoint/ckpt-0.index (deflated 80%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/checkpoint/checkpoint (deflated 41%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/export/checkpoint/ckpt-0.data-00000-of-00001 (deflated 8%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport/ (stored 0%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport/group1-shard3of3.bin (deflated 7%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport/group1-shard2of3.bin (deflated 7%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport/model.json (deflated 96%)
#   adding: content/Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport/group1-shard1of3.bin (deflated 16%)
#   adding: content/Tensorflow/workspace/models/.ipynb_checkpoints/ (stored 0%)
#   adding: content/Tensorflow/workspace/annotations/ (stored 0%)
#   adding: content/Tensorflow/workspace/annotations/label_map.pbtxt (deflated 52%)
#   adding: content/Tensorflow/workspace/images/ (stored 0%)
#   adding: content/Tensorflow/workspace/images/train/ (stored 0%)
#   adding: content/Tensorflow/workspace/images/train/hello4.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello12.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello7.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no3.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou9.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes15.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes5.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou9.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks13.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello13.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou5.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello12.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no15.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes13.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/yes1.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks9.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/train/hello3.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks10.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks11.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou3.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks8.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/train/no5.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks1.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes2.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello2.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no13.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no11.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou13.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/yes3.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/yes12.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes8.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello5.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks7.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello9.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou6.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello13.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no13.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks2.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no2.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou15.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no3.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no14.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello11.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/yes9.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no4.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no6.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou13.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou14.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/train/thanks15.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks6.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no15.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no11.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no5.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks6.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/yes13.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes5.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes7.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou7.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello6.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou14.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes4.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou12.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou8.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou11.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no12.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou15.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello10.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/yes14.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks14.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes15.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks11.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello1.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes7.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello1.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello7.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no4.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no7.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello8.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello11.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks8.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou6.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes1.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no10.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes9.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks2.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/train/thanks15.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello4.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello2.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no7.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes6.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello6.xml (deflated 44%)
#   adding: content/Tensorflow/workspace/images/train/yes4.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou7.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou12.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks9.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no6.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no12.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello3.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no14.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no10.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks3.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes2.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/no1.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello8.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks7.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/train/yes3.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks13.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks14.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou11.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks1.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/yes12.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello9.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/hello5.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks12.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks10.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou8.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou4.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no1.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/yes6.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/yes8.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/thanks12.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/train/yes14.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou5.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou4.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/hello10.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/thanks3.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/train/no2.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou10.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou3.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/train/iloveyou10.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/.ipynb_checkpoints/ (stored 0%)
#   adding: content/Tensorflow/workspace/images/test/ (stored 0%)
#   adding: content/Tensorflow/workspace/images/test/iloveyou1.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/test/yes10.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/no9.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/thanks4.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/test/thanks5.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/hello15.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/test/no9.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/test/thanks4.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/iloveyou2.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/yes11.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/test/no8.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/iloveyou2.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/test/hello15.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/thanks5.xml (deflated 42%)
#   adding: content/Tensorflow/workspace/images/test/yes11.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/hello14.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/test/hello14.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/iloveyou1.jpeg (deflated 0%)
#   adding: content/Tensorflow/workspace/images/test/yes10.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/images/test/no8.xml (deflated 43%)
#   adding: content/Tensorflow/workspace/pre-trained-models/ (stored 0%)
#   adding: content/Tensorflow/scripts/ (stored 0%)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/Tensorflow, 'w') as f:
  f.write('content')
# Out:
#   File "<ipython-input-27-22e2eb77ffa8>", line 1
#     with open('/content/Tensorflow, 'w') as f:
#                                      ^
# SyntaxError: invalid syntax

# %%
# %cd drive/My
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive'
# /content/drive

# %%
# Out:
# MyDrive

# %%
# !ls
# Out:
# MyDrive
